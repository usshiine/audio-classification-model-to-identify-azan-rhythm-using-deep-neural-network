# %%
import pandas as pd #untuk memproses data, manipulasi data, dan analisis data
import numpy as np #fungsi untuk aljabar linier dan pembuatan bilangan acak
import matplotlib.pyplot as plt #untuk visualisasi data seperti plot, histogram, bar chart, dll
# %matplotlib inline
import seaborn as sns #untuk menampilkan visualisasi data lebih menarik
import librosa
import librosa.display
import resampy

from scipy import signal
import tensorflow as tf
import IPython.display as ipd

import pickle
from pickle import load

import pandas as pd

import os

#--Sklearn library-- membantu melakukan processing data ataupun melakukan training data
from sklearn.model_selection import train_test_split #membagi data secara acak
from sklearn.metrics import confusion_matrix, classification_report #untuk memplot confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay #untuk memplot confusion matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score #model performance
from sklearn import metrics

import warnings

warnings.filterwarnings('ignore') # To supress warnings
 # set the background for the graphs
plt.style.use('ggplot')

# %%
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name)

    emphasized_audio = librosa.effects.preemphasis(y=audio, coef=0.97)

    mfccs_features = librosa.feature.mfcc(y=emphasized_audio,
                                          n_fft=2048,
                                          hop_length=512,
                                          sr=44100,
                                          window='hamming',
                                          dct_type=2,
                                          n_mfcc=20)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)

    return mfccs_scaled_features

def extract_mfcc_from_folders(folder_paths):
    all_mfccs = []
    all_labels = []

    for i, folder_path in enumerate(folder_paths):
        label = i  # Assign a unique label to each class
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            if os.path.isfile(file_path) and filename.endswith('.wav'):
                mfccs = features_extractor(file_path)
                all_mfccs.append(mfccs)
                all_labels.append(label)

    return np.array(all_mfccs), np.array(all_labels)

# Define paths to the training and testing folders for each class
training_folder_paths = [
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\training\ajam',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\training\bayati',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\training\hijaz',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\training\nahawand',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\training\rast'
]

testing_folder_paths = [
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\testing\ajam',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\testing\bayati',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\testing\hijaz',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\testing\nahawand',
    r'C:\Users\ushine\Data Mining\Azan Sukses\split_azan_original_dataset\testing\rast'
]

# Extract MFCCs and labels from training data
training_mfccs, training_labels = extract_mfcc_from_folders(training_folder_paths)

# Extract MFCCs and labels from testing data
testing_mfccs, testing_labels = extract_mfcc_from_folders(testing_folder_paths)

# Display the shape of the resulting arrays
print("Training MFCCs shape:", training_mfccs.shape)
print("Training Labels shape:", training_labels.shape)
print("Testing MFCCs shape:", testing_mfccs.shape)
print("Testing Labels shape:", testing_labels.shape)

# Save extracted features and labels using pickle
training_data = {'features': training_mfccs, 'labels': training_labels}
testing_data = {'features': testing_mfccs, 'labels': testing_labels}

with open('./Training_Data.pkl', 'wb') as f:
    pickle.dump(training_data, f)

with open('./Testing_Data.pkl', 'wb') as f:
    pickle.dump(testing_data, f)

# Load extracted features and labels using pickle
with open('./Training_Data.pkl', 'rb') as f:
    training_data = pickle.load(f)

with open('./Testing_Data.pkl', 'rb') as f:
    testing_data = pickle.load(f)

# Create DataFrames for training and testing data
training_df = pd.DataFrame({'feature': training_data['features'].tolist(), 'label': training_data['labels']})
testing_df = pd.DataFrame({'feature': testing_data['features'].tolist(), 'label': testing_data['labels']})

# Rename labels
label_mapping = {0: 'ajam', 1: 'bayati', 2: 'hijaz', 3: 'nahawand', 4: 'rast'}
training_df['label'] = training_df['label'].map(label_mapping)
testing_df['label'] = testing_df['label'].map(label_mapping)
# Out:
# Training MFCCs shape: (200, 20)
# Training Labels shape: (200,)
# Testing MFCCs shape: (50, 20)
# Testing Labels shape: (50,)

# %%
# Tampilkan seluruh data dari DataFrame training_df
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print("Training DataFrame:")
training_df
# Out:
# Training DataFrame:
#                                                feature     label
# 0    [-355.3324890136719, 10.84214973449707, -70.06...      ajam
# 1    [-370.8905029296875, 23.20957374572754, -146.6...      ajam
# 2    [-496.2208251953125, -28.793537139892578, -31....      ajam
# 3    [-460.273681640625, -18.98396873474121, -5.502...      ajam
# 4    [-528.2042846679688, 9.478331565856934, -24.36...      ajam
# 5    [-340.9193115234375, -74.26519775390625, -44.5...      ajam
# 6    [-339.01513671875, -27.49043083190918, -35.869...      ajam
# 7    [-321.5217590332031, -25.57415008544922, -33.4...      ajam
# 8    [-351.2911376953125, -36.08087158203125, -43.8...      ajam
# 9    [-284.54364013671875, -64.58732604980469, -44....      ajam
# 10   [-381.07763671875, -24.894676208496094, -35.36...      ajam
# 11   [-338.6885070800781, -37.81884002685547, -66.6...      ajam
# 12   [-305.6313781738281, -37.82670974731445, -53.9...      ajam
# 13   [-294.67279052734375, -39.83021926879883, -56....      ajam
# 14   [-369.1254577636719, 0.7360641956329346, -28.5...      ajam
# 15   [-373.96319580078125, 1.9305466413497925, -30....      ajam
# 16   [-377.3083801269531, -9.141030311584473, -30.3...      ajam
# 17   [-365.80364990234375, -13.475471496582031, -41...      ajam
# 18   [-406.2578125, -58.94660568237305, -42.1951599...      ajam
# 19   [-364.8788757324219, -31.620229721069336, -78....      ajam
# 20   [-372.03411865234375, -44.52043914794922, -43....      ajam
# 21   [-284.4729919433594, -70.5050048828125, -59.23...      ajam
# 22   [-264.542724609375, -71.4850845336914, -68.229...      ajam
# 23   [-264.47802734375, -88.85833740234375, -66.658...      ajam
# 24   [-379.1693115234375, -59.22724914550781, -62.2...      ajam
# 25   [-301.19232177734375, 10.945488929748535, -78....      ajam
# 26   [-239.44076538085938, 7.847367763519287, -71.5...      ajam
# 27   [-368.3122863769531, 56.08707046508789, -59.16...      ajam
# 28   [-453.55194091796875, -12.774097442626953, -38...      ajam
# 29   [-241.65928649902344, -45.40065383911133, -86....      ajam
# 30   [-323.2608337402344, -41.76994323730469, -50.8...      ajam
# 31   [-326.89990234375, -35.82624816894531, -40.838...      ajam
# 32   [-355.31488037109375, -41.65952682495117, -59....      ajam
# 33   [-414.9900207519531, -36.248558044433594, -32....      ajam
# 34   [-412.33111572265625, -34.23246383666992, -31....      ajam
# 35   [-420.7254943847656, -39.99543380737305, -25.0...      ajam
# 36   [-372.3619689941406, 38.7161865234375, -83.058...      ajam
# 37   [-408.7173156738281, 28.113386154174805, -62.5...      ajam
# 38   [-384.21142578125, -13.798962593078613, -70.01...      ajam
# 39   [-224.8395538330078, -63.40578842163086, -17.0...      ajam
# 40   [-226.90907287597656, -50.07405090332031, -71....    bayati
# 41   [-431.1749572753906, -7.84849739074707, -89.15...    bayati
# 42   [-265.2412109375, -5.488009452819824, -91.2431...    bayati
# 43   [-233.3292694091797, -30.752811431884766, -79....    bayati
# 44   [-313.4983215332031, -84.6779556274414, -48.78...    bayati
# 45   [-344.5413818359375, 36.68410873413086, -78.85...    bayati
# 46   [-404.5218811035156, 0.7465407252311707, -38.0...    bayati
# 47   [-374.167724609375, -15.608445167541504, -45.9...    bayati
# 48   [-361.6333312988281, -44.215938568115234, -47....    bayati
# 49   [-251.8483428955078, -73.78307342529297, -76.8...    bayati
# 50   [-396.1561279296875, -14.845041275024414, -27....    bayati
# 51   [-299.75732421875, -33.1333122253418, -48.2124...    bayati
# 52   [-276.12322998046875, -51.04426956176758, -71....    bayati
# 53   [-280.13128662109375, -51.18593215942383, -72....    bayati
# 54   [-291.31121826171875, -45.60491180419922, -62....    bayati
# 55   [-397.7833557128906, 0.05548993870615959, -27....    bayati
# 56   [-378.1487121582031, 0.26465466618537903, -39....    bayati
# 57   [-362.09979248046875, 0.8853868842124939, -42....    bayati
# 58   [-377.0989990234375, -4.966333866119385, -41.3...    bayati
# 59   [-254.1982879638672, -5.9865546226501465, -67....    bayati
# 60   [-413.2190856933594, -34.97958755493164, -32.5...    bayati
# 61   [-399.112548828125, -41.804752349853516, -42.6...    bayati
# 62   [-423.48284912109375, -43.503211975097656, -37...    bayati
# 63   [-409.7981262207031, -46.71617889404297, -36.8...    bayati
# 64   [-372.580322265625, 27.50960922241211, -41.602...    bayati
# 65   [-332.4129638671875, -6.93414306640625, -77.35...    bayati
# 66   [-330.47406005859375, -11.286542892456055, -77...    bayati
# 67   [-292.22149658203125, 4.192478179931641, -124....    bayati
# 68   [-277.6740417480469, -93.67052459716797, -86.9...    bayati
# 69   [-343.9183349609375, -41.1190071105957, -53.84...    bayati
# 70   [-327.1363220214844, -46.162967681884766, -54....    bayati
# 71   [-327.54315185546875, -31.054990768432617, -61...    bayati
# 72   [-313.76666259765625, -42.67058563232422, -56....    bayati
# 73   [-398.30279541015625, -42.55740737915039, -31....    bayati
# 74   [-370.0032958984375, -26.067197799682617, -33....    bayati
# 75   [-358.9518737792969, -41.57752227783203, -41.3...    bayati
# 76   [-246.96969604492188, -3.8791286945343018, -76...    bayati
# 77   [-399.4019775390625, -4.51969575881958, -100.2...    bayati
# 78   [-312.41680908203125, -35.548980712890625, -56...    bayati
# 79   [-261.109130859375, -84.65924072265625, -86.06...    bayati
# 80   [-340.73895263671875, 22.463146209716797, -111...     hijaz
# 81   [-315.9993591308594, -61.434879302978516, -62....     hijaz
# 82   [-331.4815368652344, -53.572513580322266, -122...     hijaz
# 83   [-218.4220733642578, -56.15818786621094, -85.5...     hijaz
# 84   [-246.7050323486328, 27.700603485107422, -100....     hijaz
# 85   [-489.949462890625, 10.262216567993164, -55.53...     hijaz
# 86   [-409.36871337890625, -6.11515474319458, -31.2...     hijaz
# 87   [-422.009765625, -5.758760929107666, -46.91728...     hijaz
# 88   [-389.9219665527344, -32.170555114746094, -40....     hijaz
# 89   [-367.0463562011719, -41.62533187866211, -61.6...     hijaz
# 90   [-374.22210693359375, -19.911588668823242, -30...     hijaz
# 91   [-332.9116516113281, -6.268693923950195, -35.0...     hijaz
# 92   [-337.9022521972656, -11.833267211914062, -39....     hijaz
# 93   [-357.9010314941406, -28.185134887695312, -44....     hijaz
# 94   [-369.2661437988281, -6.111439228057861, -24.7...     hijaz
# 95   [-333.0675964355469, -19.485342025756836, -36....     hijaz
# 96   [-369.1826477050781, 5.244677543640137, -25.61...     hijaz
# 97   [-358.3158264160156, -12.690628051757812, -32....     hijaz
# 98   [-374.541015625, -39.28202438354492, -38.04990...     hijaz
# 99   [-350.4015808105469, -55.842655181884766, -72....     hijaz
# 100  [-366.2872314453125, -54.798824310302734, -48....     hijaz
# 101  [-386.6938781738281, -55.7078857421875, -38.73...     hijaz
# 102  [-424.2357177734375, -6.414141654968262, -52.2...     hijaz
# 103  [-408.43408203125, -15.916860580444336, -49.82...     hijaz
# 104  [-457.8134460449219, -32.696983337402344, -52....     hijaz
# 105  [-450.095458984375, -5.645705699920654, -13.74...     hijaz
# 106  [-423.8681945800781, -3.784775733947754, -12.6...     hijaz
# 107  [-321.54931640625, -8.728729248046875, -48.126...     hijaz
# 108  [-368.1608581542969, -72.51527404785156, -47.6...     hijaz
# 109  [-345.2278137207031, -18.871580123901367, -52....     hijaz
# 110  [-491.2886962890625, -12.724759101867676, -30....     hijaz
# 111  [-361.00079345703125, -26.644899368286133, -46...     hijaz
# 112  [-364.5284118652344, -44.60446548461914, -49.6...     hijaz
# 113  [-414.4129638671875, -34.425567626953125, -18....     hijaz
# 114  [-509.6535949707031, -32.1939811706543, -16.49...     hijaz
# 115  [-469.898681640625, -11.910982131958008, -30.6...     hijaz
# 116  [-483.3439636230469, -28.20476722717285, -28.8...     hijaz
# 117  [-489.283447265625, -36.45384216308594, -25.62...     hijaz
# 118  [-483.8782653808594, -23.3179988861084, -63.50...     hijaz
# 119  [-406.1057434082031, -80.74993896484375, -46.1...     hijaz
# 120  [-327.7545166015625, -37.281944274902344, -50....  nahawand
# 121  [-306.4259338378906, -20.10964584350586, -23.3...  nahawand
# 122  [-363.2187805175781, -35.4674072265625, -104.7...  nahawand
# 123  [-362.4371337890625, 10.341230392456055, -56.7...  nahawand
# 124  [-218.36305236816406, 13.56041145324707, -76.7...  nahawand
# 125  [-252.81130981445312, -80.68712615966797, -51....  nahawand
# 126  [-312.7286682128906, -40.4567985534668, -44.14...  nahawand
# 127  [-323.1383972167969, -43.03364944458008, -31.8...  nahawand
# 128  [-325.5008239746094, -40.04527282714844, -48.3...  nahawand
# 129  [-251.2547607421875, -69.21781921386719, -61.4...  nahawand
# 130  [-349.8291931152344, -23.709489822387695, -40....  nahawand
# 131  [-323.05206298828125, -10.357478141784668, -52...  nahawand
# 132  [-323.05206298828125, -10.357478141784668, -52...  nahawand
# 133  [-315.8395080566406, -12.827914237976074, -43....  nahawand
# 134  [-340.96099853515625, 1.9779787063598633, -35....  nahawand
# 135  [-352.8662414550781, -7.320630073547363, -34.9...  nahawand
# 136  [-363.61517333984375, -1.834160566329956, -43....  nahawand
# 137  [-359.47882080078125, -10.735238075256348, -35...  nahawand
# 138  [-366.3080139160156, -9.594804763793945, -46.2...  nahawand
# 139  [-269.1134033203125, -55.105934143066406, -80....  nahawand
# 140  [-334.6109619140625, 20.228384017944336, -51.0...  nahawand
# 141  [-331.4415588378906, 44.36393737792969, -55.82...  nahawand
# 142  [-309.5213623046875, -35.018775939941406, -36....  nahawand
# 143  [-274.15240478515625, -42.783451080322266, -53...  nahawand
# 144  [-287.78729248046875, -64.13661193847656, -53....  nahawand
# 145  [-304.75, 24.357280731201172, -70.366737365722...  nahawand
# 146  [-375.8593444824219, 44.40132522583008, -105.2...  nahawand
# 147  [-231.33815002441406, -23.65557098388672, -78....  nahawand
# 148  [-389.4811706542969, 39.104766845703125, -116....  nahawand
# 149  [-394.8721618652344, 19.3523006439209, -117.69...  nahawand
# 150  [-310.576416015625, -21.228925704956055, -51.8...  nahawand
# 151  [-288.6729736328125, -41.542335510253906, -55....  nahawand
# 152  [-305.62091064453125, -52.96916580200195, -49....  nahawand
# 153  [-390.43524169921875, -28.015308380126953, -50...  nahawand
# 154  [-398.63580322265625, -17.31734275817871, -38....  nahawand
# 155  [-379.5062561035156, -22.80518913269043, -44.5...  nahawand
# 156  [-166.58279418945312, -16.763347625732422, -73...  nahawand
# 157  [-333.063720703125, -52.570987701416016, -115....  nahawand
# 158  [-262.5498352050781, 15.758964538574219, -21.7...  nahawand
# 159  [-317.94580078125, -29.972118377685547, -102.7...  nahawand
# 160  [-699.2233276367188, -5.887683868408203, -19.2...      rast
# 161  [-553.1326904296875, 21.009260177612305, -49.3...      rast
# 162  [-471.82745361328125, 3.0566256046295166, -15....      rast
# 163  [-499.0901794433594, -10.592461585998535, -25....      rast
# 164  [-400.9927673339844, -17.955806732177734, -57....      rast
# 165  [-538.1697387695312, -29.094852447509766, -35....      rast
# 166  [-395.83758544921875, -44.57742691040039, -31....      rast
# 167  [-420.41845703125, -20.534378051757812, -22.58...      rast
# 168  [-452.5450134277344, -12.782383918762207, -23....      rast
# 169  [-434.455810546875, -31.81352996826172, -40.40...      rast
# 170  [-445.1953125, -20.508731842041016, -13.906960...      rast
# 171  [-437.7948303222656, 0.9894219040870667, -42.3...      rast
# 172  [-357.71978759765625, -42.29469680786133, -38....      rast
# 173  [-415.43011474609375, -17.738086700439453, -26...      rast
# 174  [-401.97308349609375, -7.929027080535889, -28....      rast
# 175  [-363.5336608886719, -18.640953063964844, -34....      rast
# 176  [-403.8324890136719, -12.027040481567383, -25....      rast
# 177  [-387.1737976074219, -7.819160461425781, -29.3...      rast
# 178  [-564.0484619140625, 8.889411926269531, -20.59...      rast
# 179  [-585.7714233398438, -18.911518096923828, -18....      rast
# 180  [-508.9574279785156, -26.90043830871582, -14.7...      rast
# 181  [-483.6783447265625, -28.42934799194336, -11.8...      rast
# 182  [-487.7389831542969, -40.856685638427734, -21....      rast
# 183  [-614.4420166015625, 0.9957241415977478, -10.5...      rast
# 184  [-589.4724731445312, -23.770610809326172, -12....      rast
# 185  [-479.66070556640625, 8.716646194458008, -41.1...      rast
# 186  [-554.3856201171875, -10.184645652770996, -9.3...      rast
# 187  [-422.3906555175781, -13.120985984802246, -55....      rast
# 188  [-580.9678955078125, -8.344962120056152, -27.9...      rast
# 189  [-544.9776000976562, -3.006237030029297, -2.95...      rast
# 190  [-464.7990417480469, -18.094558715820312, -33....      rast
# 191  [-426.4123840332031, -34.7078971862793, -28.27...      rast
# 192  [-474.8453674316406, -33.776756286621094, -30....      rast
# 193  [-479.8648681640625, -22.3654842376709, -12.11...      rast
# 194  [-476.2193298339844, -39.08935546875, -16.7508...      rast
# 195  [-496.0766906738281, -41.76844024658203, -16.1...      rast
# 196  [-485.7694396972656, -39.234764099121094, -15....      rast
# 197  [-590.2845458984375, 4.067625999450684, -17.65...      rast
# 198  [-342.8443603515625, -13.319212913513184, -51....      rast
# 199  [-445.48602294921875, -62.78251266479492, -24....      rast

# %%
# Tampilkan seluruh data dari DataFrame testing_df
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print("\nTesting DataFrame:")
testing_df
# Out:
# Testing DataFrame:
#                                               feature     label
# 0   [-261.309814453125, -52.8917121887207, -51.763...      ajam
# 1   [-341.371826171875, -14.449501991271973, -38.6...      ajam
# 2   [-328.07708740234375, -33.22261428833008, -64....      ajam
# 3   [-313.66558837890625, -52.88821792602539, -51....      ajam
# 4   [-264.9950256347656, -17.595029830932617, -60....      ajam
# 5   [-332.1094055175781, -43.8901252746582, -55.57...      ajam
# 6   [-449.77001953125, -34.71723937988281, -26.544...      ajam
# 7   [-286.5934143066406, 10.128998756408691, -83.1...      ajam
# 8   [-360.81683349609375, 25.00119972229004, -27.1...      ajam
# 9   [-245.28182983398438, -47.73829650878906, -74....      ajam
# 10  [-355.3559875488281, -57.42397689819336, -80.6...    bayati
# 11  [-376.0110168457031, -18.256139755249023, -30....    bayati
# 12  [-276.8575744628906, -41.92220687866211, -67.2...    bayati
# 13  [-336.69708251953125, 28.30626678466797, -83.1...    bayati
# 14  [-324.9411315917969, -9.097601890563965, -55.4...    bayati
# 15  [-357.344482421875, -28.095714569091797, -48.0...    bayati
# 16  [-439.38641357421875, -33.456058502197266, -26...    bayati
# 17  [-192.78839111328125, -35.99998474121094, -93....    bayati
# 18  [-336.7085876464844, -14.791462898254395, -75....    bayati
# 19  [-237.3811798095703, -67.96636199951172, -56.7...    bayati
# 20  [-347.19140625, -33.0439453125, -60.2950363159...     hijaz
# 21  [-443.53399658203125, 2.9051930904388428, -27....     hijaz
# 22  [-261.268798828125, -81.6708984375, -66.200958...     hijaz
# 23  [-359.8931884765625, -41.673377990722656, -52....     hijaz
# 24  [-437.4607849121094, -5.351240158081055, -24.1...     hijaz
# 25  [-439.67425537109375, -24.269866943359375, -34...     hijaz
# 26  [-429.85760498046875, -54.532630920410156, -20...     hijaz
# 27  [-332.2063293457031, -14.293891906738281, -68....     hijaz
# 28  [-318.7396545410156, -19.176633834838867, -52....     hijaz
# 29  [-388.0999755859375, 4.341826438903809, -51.97...     hijaz
# 30  [-314.9510192871094, -3.643529176712036, -104....  nahawand
# 31  [-323.2154846191406, -43.009178161621094, -31....  nahawand
# 32  [-291.96710205078125, -33.06898498535156, -56....  nahawand
# 33  [-321.17724609375, 22.95698356628418, -50.4267...  nahawand
# 34  [-301.34912109375, -57.16359329223633, -53.001...  nahawand
# 35  [-332.73504638671875, -19.541194915771484, -52...  nahawand
# 36  [-360.3569030761719, -40.09140396118164, -44.0...  nahawand
# 37  [-410.5476989746094, 46.082706451416016, -106....  nahawand
# 38  [-253.36766052246094, -41.00492477416992, -96....  nahawand
# 39  [-330.8589172363281, -87.45368957519531, -72.9...  nahawand
# 40  [-321.8938293457031, 22.875280380249023, -92.5...      rast
# 41  [-443.6171875, -7.654126167297363, -22.5473289...      rast
# 42  [-430.6971435546875, -3.8764030933380127, -36....      rast
# 43  [-517.1510620117188, -15.065479278564453, -14....      rast
# 44  [-526.1852416992188, -21.93686866760254, -6.26...      rast
# 45  [-451.14404296875, -30.11229705810547, -37.710...      rast
# 46  [-517.86962890625, -21.741363525390625, -13.45...      rast
# 47  [-335.714599609375, -53.888877868652344, -44.1...      rast
# 48  [-596.6399536132812, -2.2420942783355713, -6.8...      rast
# 49  [-541.4566650390625, -31.138412475585938, -31....      rast

# %%
# Extract features and labels from training DataFrame
X_train = np.array(training_df['feature'].tolist())
y_train = np.array(training_df['label'].tolist())

# Extract features and labels from testing DataFrame
X_test = np.array(testing_df['feature'].tolist())
y_test = np.array(testing_df['label'].tolist())

# Display the shape of the resulting arrays
print("Training Features shape:", X_train.shape)
print("Training Labels shape:", y_train.shape)
print("Testing Features shape:", X_test.shape)
print("Testing Labels shape:", y_test.shape)
# Out:
# Training Features shape: (200, 20)
# Training Labels shape: (200,)
# Testing Features shape: (50, 20)
# Testing Labels shape: (50,)

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert labels to numerical encoding
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.fit_transform(y_test)

# %%
y_train = to_categorical(y_train_encoded)
y_test = to_categorical(y_test_encoded)

# %%
import numpy as np
import time
import random
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold


# Best Hyperparameters from Grid Search
best_hyperparameters = {'dropout_rate1': 0.4, 'dropout_rate2': 0.3, 'dropout_rate3': 0.1, 
                        'learning_rate': 0.001, 'units_layer1': 1024, 'units_layer2': 512, 
                        'units_layer3': 256, 'units_layer4': 128, 'units_layer5': 64}


# Inisialisasi K-Fold Cross Validation
kf = KFold(n_splits=10, shuffle=True, random_state=random.randint(1, 1000))
fold = 1

losses = []  # Untuk menyimpan hasil loss
train_accuracies = []  # Untuk menyimpan hasil akurasi training
testing_accuracies = []  # Untuk menyimpan hasil akurasi testing
histories = [] # Untuk menyimpan hasil model
training_times = [] # Untuk menyimpan waktu pelatihan setiap fold
all_predictions = []
precicion_scores = []
recall_scores = []
f1_scores = []  # Untuk menyimpan F1 score dari setiap fold
classification_reports = [] #Untuk menyimpan laporan klasifikasi

# Loop melalui setiap lipatan
for train_index, test_index in kf.split(X_train, y_train):
    X_train_fold, X_test_fold = X_train[train_index], X_train[test_index]
    y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
    
    # Persentase pembagian data training dan testing
    percentage_train = len(train_index) / len(X_train) * 100
    percentage_test = len(test_index) / len(X_train) * 100

    # Inisialisasi model neural network dengan menggunakan parameter terbaik
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(units=best_hyperparameters['units_layer1'], input_shape=(20,), activation="relu"))
    model.add(tf.keras.layers.Dropout(best_hyperparameters['dropout_rate1']))
    model.add(tf.keras.layers.Dense(units=best_hyperparameters['units_layer2'], activation="relu"))
    model.add(tf.keras.layers.Dropout(best_hyperparameters['dropout_rate2']))
    model.add(tf.keras.layers.Dense(units=best_hyperparameters['units_layer3'], activation="relu"))
    model.add(tf.keras.layers.Dropout(best_hyperparameters['dropout_rate3']))
    model.add(tf.keras.layers.Dense(units=best_hyperparameters['units_layer4'], activation="relu"))
    model.add(tf.keras.layers.Dense(units=best_hyperparameters['units_layer5'], activation="relu"))
    model.add(tf.keras.layers.Dense(units=5, activation="softmax"))

    # Kompilasi model
    optimizer = tf.keras.optimizers.Adam(best_hyperparameters['learning_rate'])
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    # Catat waktu awal
    start_time = time.time()
    
    # Tampilkan Keterangan Fold
    print(f"Fold {fold}")
    
    # Print persentase pembagian data training dan testing
    print(f"Percentage of Data for Training: {percentage_train:.2f}%")
    print(f"Percentage of Data for Testing: {percentage_test:.2f}%")

    # Latih model
    history = model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=64)
    histories.append(history)
    model.summary()

    # Catat waktu selesai
    end_time = time.time()

    # Hitung waktu eksekusi
    elapsed_time = end_time - start_time
    training_times.append(elapsed_time)

    # Evaluasi model
    loss, accuracy = model.evaluate(X_train_fold, y_train_fold)
    losses.append(loss)
    train_accuracies.append(accuracy)

    # Prediksi model
    pred = model.predict(X_test_fold)
    pred_ = np.argmax(pred, axis=1)
    pred_ = label_encoder.inverse_transform(pred_)
    true_y = label_encoder.inverse_transform(np.argmax(to_categorical(y_test_fold), axis=1)[:, 1])

    # Menyimpan hasil prediksi dari fold tertentu
    fold_predictions = {'true_labels': true_y, 'predicted_labels': pred_}
    all_predictions.append(fold_predictions)
    
    # Hitung testing akurasi pada fold tertentu
    accuracy_test = accuracy_score(true_y, pred_)
    testing_accuracies.append(accuracy_test)

    # Menghitung Precision, Recall, F1 Score
    precision = precision_score(true_y, pred_, average=None)
    precicion_scores.append(precision)

    recall = recall_score(true_y, pred_, average=None)
    recall_scores.append(recall)

    f1 = f1_score(true_y, pred_, average=None)
    f1_scores.append(f1)

    # Hitung laporan klasifikasi
    report = classification_report(true_y, pred_)
    classification_reports.append(report)

    
    fold += 1
# Out:
# Fold 1
# Percentage of Data for Training: 90.00%
# Percentage of Data for Testing: 10.00%
# Epoch 1/100
# 3/3 [==============================] - 6s 73ms/step - loss: 12.6712 - accuracy: 0.2000
# Epoch 2/100
# 3/3 [==============================] - 0s 31ms/step - loss: 5.5620 - accuracy: 0.2444
# Epoch 3/100
# 3/3 [==============================] - 0s 31ms/step - loss: 4.2499 - accuracy: 0.2278
# Epoch 4/100
# 3/3 [==============================] - 0s 72ms/step - loss: 3.3999 - accuracy: 0.2278
# Epoch 5/100
# 3/3 [==============================] - 0s 64ms/step - loss: 3.1596 - accuracy: 0.2222
# Epoch 6/100
# 3/3 [==============================] - 0s 98ms/step - loss: 3.0784 - accuracy: 0.2278
# Epoch 7/100
# 3/3 [==============================] - 0s 44ms/step - loss: 2.6269 - accuracy: 0.2167
# Epoch 8/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.4598 - accuracy: 0.2000
# Epoch 9/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2031 - accuracy: 0.2500
# Epoch 10/100
# 3/3 [==============================] - 0s 51ms/step - loss: 2.0349 - accuracy: 0.2667
# Epoch 11/100
# 3/3 [==============================] - 0s 47ms/step - loss: 2.1526 - accuracy: 0.2444
# Epoch 12/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.9083 - accuracy: 0.2833
# Epoch 13/100
# 3/3 [==============================] - 0s 52ms/step - loss: 1.9590 - accuracy: 0.1833
# Epoch 14/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.7911 - accuracy: 0.2833
# Epoch 15/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.7995 - accuracy: 0.3278
# Epoch 16/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.7642 - accuracy: 0.2889
# Epoch 17/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.7209 - accuracy: 0.2889
# Epoch 18/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.6539 - accuracy: 0.3111
# Epoch 19/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.6565 - accuracy: 0.3056
# Epoch 20/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.6332 - accuracy: 0.3056
# Epoch 21/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6359 - accuracy: 0.3167
# Epoch 22/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6445 - accuracy: 0.2833
# Epoch 23/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6304 - accuracy: 0.2778
# Epoch 24/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.5228 - accuracy: 0.3556
# Epoch 25/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5344 - accuracy: 0.3389
# Epoch 26/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.5979 - accuracy: 0.3222
# Epoch 27/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.5302 - accuracy: 0.3611
# Epoch 28/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.5309 - accuracy: 0.3333
# Epoch 29/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.5611 - accuracy: 0.3722
# Epoch 30/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.5191 - accuracy: 0.3667
# Epoch 31/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4151 - accuracy: 0.3556
# Epoch 32/100
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4709 - accuracy: 0.3333
# Epoch 33/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.4442 - accuracy: 0.3722
# Epoch 34/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4586 - accuracy: 0.3389
# Epoch 35/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4721 - accuracy: 0.3667
# Epoch 36/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.4311 - accuracy: 0.3222
# Epoch 37/100
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4401 - accuracy: 0.3111
# Epoch 38/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.4523 - accuracy: 0.3333
# Epoch 39/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4151 - accuracy: 0.3944
# Epoch 40/100
# 3/3 [==============================] - 0s 66ms/step - loss: 1.4291 - accuracy: 0.4000
# Epoch 41/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4014 - accuracy: 0.3444
# Epoch 42/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.3877 - accuracy: 0.3500
# Epoch 43/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3811 - accuracy: 0.3333
# Epoch 44/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3678 - accuracy: 0.4000
# Epoch 45/100
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4757 - accuracy: 0.3667
# Epoch 46/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3422 - accuracy: 0.4167
# Epoch 47/100
# 3/3 [==============================] - 0s 82ms/step - loss: 1.4200 - accuracy: 0.3833
# Epoch 48/100
# 3/3 [==============================] - 0s 68ms/step - loss: 1.3698 - accuracy: 0.3833
# Epoch 49/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3507 - accuracy: 0.3944
# Epoch 50/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.3897 - accuracy: 0.3611
# Epoch 51/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.3104 - accuracy: 0.4167
# Epoch 52/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.3085 - accuracy: 0.4556
# Epoch 53/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3256 - accuracy: 0.4111
# Epoch 54/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.2712 - accuracy: 0.4222
# Epoch 55/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3414 - accuracy: 0.3889
# Epoch 56/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.3665 - accuracy: 0.3833
# Epoch 57/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.2778 - accuracy: 0.4667
# Epoch 58/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3180 - accuracy: 0.4056
# Epoch 59/100
# 3/3 [==============================] - 0s 68ms/step - loss: 1.2716 - accuracy: 0.4000
# Epoch 60/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.2534 - accuracy: 0.4111
# Epoch 61/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2948 - accuracy: 0.4111
# Epoch 62/100
# 3/3 [==============================] - 0s 101ms/step - loss: 1.3394 - accuracy: 0.4111
# Epoch 63/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.2932 - accuracy: 0.3944
# Epoch 64/100
# 3/3 [==============================] - 0s 81ms/step - loss: 1.1849 - accuracy: 0.4667
# Epoch 65/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.2601 - accuracy: 0.3556
# Epoch 66/100
# 3/3 [==============================] - 0s 75ms/step - loss: 1.2707 - accuracy: 0.4056
# Epoch 67/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2491 - accuracy: 0.4500
# Epoch 68/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2852 - accuracy: 0.4667
# Epoch 69/100
# 3/3 [==============================] - 0s 82ms/step - loss: 1.1973 - accuracy: 0.4389
# Epoch 70/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.2504 - accuracy: 0.4444
# Epoch 71/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2403 - accuracy: 0.4556
# Epoch 72/100
# 3/3 [==============================] - 0s 52ms/step - loss: 1.2374 - accuracy: 0.4611
# Epoch 73/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.2190 - accuracy: 0.4389
# Epoch 74/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2565 - accuracy: 0.4167
# Epoch 75/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2264 - accuracy: 0.4222
# Epoch 76/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2418 - accuracy: 0.4667
# Epoch 77/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.2012 - accuracy: 0.4500
# Epoch 78/100
# 3/3 [==============================] - 0s 67ms/step - loss: 1.2105 - accuracy: 0.4167
# Epoch 79/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2178 - accuracy: 0.4833
# Epoch 80/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.1529 - accuracy: 0.4833
# Epoch 81/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1135 - accuracy: 0.5111
# Epoch 82/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1439 - accuracy: 0.4667
# Epoch 83/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1247 - accuracy: 0.4944
# Epoch 84/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.1758 - accuracy: 0.4944
# Epoch 85/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1476 - accuracy: 0.4333
# Epoch 86/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0733 - accuracy: 0.5167
# Epoch 87/100
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1586 - accuracy: 0.5167
# Epoch 88/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1309 - accuracy: 0.4889
# Epoch 89/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.1178 - accuracy: 0.5222
# Epoch 90/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1277 - accuracy: 0.5222
# Epoch 91/100
# 3/3 [==============================] - 0s 83ms/step - loss: 1.1244 - accuracy: 0.4944
# Epoch 92/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0811 - accuracy: 0.5556
# Epoch 93/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1664 - accuracy: 0.4722
# Epoch 94/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.0984 - accuracy: 0.4833
# Epoch 95/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0576 - accuracy: 0.5278
# Epoch 96/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.1423 - accuracy: 0.5111
# Epoch 97/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.0827 - accuracy: 0.5389
# Epoch 98/100
# 3/3 [==============================] - 0s 78ms/step - loss: 1.0817 - accuracy: 0.5500
# Epoch 99/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1187 - accuracy: 0.5056
# Epoch 100/100
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0751 - accuracy: 0.5722
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 1024)              21504
#
#  dropout_30 (Dropout)        (None, 1024)              0
#
#  dense_61 (Dense)            (None, 512)               524800
#
#  dropout_31 (Dropout)        (None, 512)               0
#
#  dense_62 (Dense)            (None, 256)               131328
#
#  dropout_32 (Dropout)        (None, 256)               0
#
#  dense_63 (Dense)            (None, 128)               32896
#
#  dense_64 (Dense)            (None, 64)                8256
#
#  dense_65 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 719109 (2.74 MB)
# Trainable params: 719109 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 6/6 [==============================] - 2s 10ms/step - loss: 0.9643 - accuracy: 0.6278
# 1/1 [==============================] - 1s 1s/step
# Fold 2
# Percentage of Data for Training: 90.00%
# Percentage of Data for Testing: 10.00%
# Epoch 1/100
# 3/3 [==============================] - 13s 72ms/step - loss: 12.1266 - accuracy: 0.1611
# Epoch 2/100
# 3/3 [==============================] - 0s 41ms/step - loss: 6.6664 - accuracy: 0.1944
# Epoch 3/100
# 3/3 [==============================] - 0s 75ms/step - loss: 3.9230 - accuracy: 0.2222
# Epoch 4/100
# 3/3 [==============================] - 0s 88ms/step - loss: 3.5351 - accuracy: 0.2167
# Epoch 5/100
# 3/3 [==============================] - 0s 93ms/step - loss: 2.8188 - accuracy: 0.2444
# Epoch 6/100
# 3/3 [==============================] - 0s 90ms/step - loss: 2.8832 - accuracy: 0.2444
# Epoch 7/100
# 3/3 [==============================] - 0s 80ms/step - loss: 2.4983 - accuracy: 0.2278
# Epoch 8/100
# 3/3 [==============================] - 0s 65ms/step - loss: 2.2459 - accuracy: 0.2833
# Epoch 9/100
# 3/3 [==============================] - 0s 109ms/step - loss: 2.3741 - accuracy: 0.2000
# Epoch 10/100
# 3/3 [==============================] - 0s 34ms/step - loss: 2.0730 - accuracy: 0.2111
# Epoch 11/100
# 3/3 [==============================] - 0s 100ms/step - loss: 2.2195 - accuracy: 0.2222
# Epoch 12/100
# 3/3 [==============================] - 0s 89ms/step - loss: 1.9128 - accuracy: 0.2611
# Epoch 13/100
# 3/3 [==============================] - 0s 82ms/step - loss: 1.8710 - accuracy: 0.2556
# Epoch 14/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.7607 - accuracy: 0.2500
# Epoch 15/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.7380 - accuracy: 0.2389
# Epoch 16/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8120 - accuracy: 0.2278
# Epoch 17/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.8070 - accuracy: 0.2611
# Epoch 18/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.8101 - accuracy: 0.2444
# Epoch 19/100
# 3/3 [==============================] - 0s 93ms/step - loss: 1.6341 - accuracy: 0.3056
# Epoch 20/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.7067 - accuracy: 0.2667
# Epoch 21/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.6246 - accuracy: 0.3056
# Epoch 22/100
# 3/3 [==============================] - 0s 81ms/step - loss: 1.5902 - accuracy: 0.2833
# Epoch 23/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.5544 - accuracy: 0.3222
# Epoch 24/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.4848 - accuracy: 0.3389
# Epoch 25/100
# 3/3 [==============================] - 0s 88ms/step - loss: 1.4928 - accuracy: 0.3556
# Epoch 26/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4813 - accuracy: 0.3444
# Epoch 27/100
# 3/3 [==============================] - 0s 94ms/step - loss: 1.5347 - accuracy: 0.3611
# Epoch 28/100
# 3/3 [==============================] - 0s 99ms/step - loss: 1.4473 - accuracy: 0.3500
# Epoch 29/100
# 3/3 [==============================] - 0s 83ms/step - loss: 1.4470 - accuracy: 0.3722
# Epoch 30/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.3978 - accuracy: 0.4167
# Epoch 31/100
# 3/3 [==============================] - 0s 80ms/step - loss: 1.4565 - accuracy: 0.3333
# Epoch 32/100
# 3/3 [==============================] - 0s 91ms/step - loss: 1.4686 - accuracy: 0.3333
# Epoch 33/100
# 3/3 [==============================] - 0s 74ms/step - loss: 1.4413 - accuracy: 0.3556
# Epoch 34/100
# 3/3 [==============================] - 0s 80ms/step - loss: 1.3604 - accuracy: 0.3722
# Epoch 35/100
# 3/3 [==============================] - 0s 89ms/step - loss: 1.4383 - accuracy: 0.3556
# Epoch 36/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3352 - accuracy: 0.4000
# Epoch 37/100
# 3/3 [==============================] - 0s 59ms/step - loss: 1.3406 - accuracy: 0.4389
# Epoch 38/100
# 3/3 [==============================] - 0s 103ms/step - loss: 1.3408 - accuracy: 0.3556
# Epoch 39/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2917 - accuracy: 0.4111
# Epoch 40/100
# 3/3 [==============================] - 0s 64ms/step - loss: 1.3724 - accuracy: 0.4222
# Epoch 41/100
# 3/3 [==============================] - 0s 113ms/step - loss: 1.3582 - accuracy: 0.3667
# Epoch 42/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.3882 - accuracy: 0.4000
# Epoch 43/100
# 3/3 [==============================] - 0s 58ms/step - loss: 1.3842 - accuracy: 0.3778
# Epoch 44/100
# 3/3 [==============================] - 0s 98ms/step - loss: 1.3070 - accuracy: 0.4056
# Epoch 45/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3190 - accuracy: 0.3833
# Epoch 46/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3779 - accuracy: 0.3500
# Epoch 47/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2832 - accuracy: 0.4167
# Epoch 48/100
# 3/3 [==============================] - 0s 88ms/step - loss: 1.3066 - accuracy: 0.4611
# Epoch 49/100
# 3/3 [==============================] - 0s 100ms/step - loss: 1.3001 - accuracy: 0.4722
# Epoch 50/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1921 - accuracy: 0.4833
# Epoch 51/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2578 - accuracy: 0.4611
# Epoch 52/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2577 - accuracy: 0.4722
# Epoch 53/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2323 - accuracy: 0.4111
# Epoch 54/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3161 - accuracy: 0.4167
# Epoch 55/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.2590 - accuracy: 0.4500
# Epoch 56/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.2578 - accuracy: 0.4611
# Epoch 57/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.2031 - accuracy: 0.4944
# Epoch 58/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.2896 - accuracy: 0.4500
# Epoch 59/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2505 - accuracy: 0.4444
# Epoch 60/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2021 - accuracy: 0.4667
# Epoch 61/100
# 3/3 [==============================] - 0s 77ms/step - loss: 1.2303 - accuracy: 0.4444
# Epoch 62/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.1983 - accuracy: 0.4444
# Epoch 63/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2405 - accuracy: 0.4556
# Epoch 64/100
# 3/3 [==============================] - 0s 94ms/step - loss: 1.1693 - accuracy: 0.5056
# Epoch 65/100
# 3/3 [==============================] - 0s 97ms/step - loss: 1.2320 - accuracy: 0.4389
# Epoch 66/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2238 - accuracy: 0.4889
# Epoch 67/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.1507 - accuracy: 0.4611
# Epoch 68/100
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1671 - accuracy: 0.5500
# Epoch 69/100
# 3/3 [==============================] - 0s 125ms/step - loss: 1.1765 - accuracy: 0.4833
# Epoch 70/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0844 - accuracy: 0.5167
# Epoch 71/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.1708 - accuracy: 0.4222
# Epoch 72/100
# 3/3 [==============================] - 0s 140ms/step - loss: 1.1594 - accuracy: 0.4778
# Epoch 73/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.1656 - accuracy: 0.4944
# Epoch 74/100
# 3/3 [==============================] - 0s 85ms/step - loss: 1.1657 - accuracy: 0.4722
# Epoch 75/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1179 - accuracy: 0.5056
# Epoch 76/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1856 - accuracy: 0.5000
# Epoch 77/100
# 3/3 [==============================] - 0s 57ms/step - loss: 1.1453 - accuracy: 0.4889
# Epoch 78/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0825 - accuracy: 0.4722
# Epoch 79/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.1172 - accuracy: 0.5444
# Epoch 80/100
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1085 - accuracy: 0.5333
# Epoch 81/100
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0490 - accuracy: 0.5500
# Epoch 82/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1146 - accuracy: 0.5167
# Epoch 83/100
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0704 - accuracy: 0.5611
# Epoch 84/100
# 3/3 [==============================] - 0s 64ms/step - loss: 1.1153 - accuracy: 0.5333
# Epoch 85/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0728 - accuracy: 0.5000
# Epoch 86/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.0965 - accuracy: 0.5278
# Epoch 87/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.9894 - accuracy: 0.5500
# Epoch 88/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1099 - accuracy: 0.5111
# Epoch 89/100
# 3/3 [==============================] - 0s 136ms/step - loss: 1.0443 - accuracy: 0.4833
# Epoch 90/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0504 - accuracy: 0.5444
# Epoch 91/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.0393 - accuracy: 0.5611
# Epoch 92/100
# 3/3 [==============================] - 0s 84ms/step - loss: 1.1374 - accuracy: 0.5389
# Epoch 93/100
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0499 - accuracy: 0.5389
# Epoch 94/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.9985 - accuracy: 0.5889
# Epoch 95/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0192 - accuracy: 0.5944
# Epoch 96/100
# 3/3 [==============================] - 0s 74ms/step - loss: 1.0516 - accuracy: 0.5333
# Epoch 97/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0071 - accuracy: 0.5833
# Epoch 98/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0187 - accuracy: 0.5556
# Epoch 99/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.0291 - accuracy: 0.5667
# Epoch 100/100
# 3/3 [==============================] - 0s 113ms/step - loss: 0.9877 - accuracy: 0.5611
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_66 (Dense)            (None, 1024)              21504
#
#  dropout_33 (Dropout)        (None, 1024)              0
#
#  dense_67 (Dense)            (None, 512)               524800
#
#  dropout_34 (Dropout)        (None, 512)               0
#
#  dense_68 (Dense)            (None, 256)               131328
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  dense_69 (Dense)            (None, 128)               32896
#
#  dense_70 (Dense)            (None, 64)                8256
#
#  dense_71 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 719109 (2.74 MB)
# Trainable params: 719109 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 6/6 [==============================] - 3s 12ms/step - loss: 0.8605 - accuracy: 0.6222
# 1/1 [==============================] - 1s 1s/step
# Fold 3
# Percentage of Data for Training: 90.00%
# Percentage of Data for Testing: 10.00%
# Epoch 1/100
# 3/3 [==============================] - 12s 30ms/step - loss: 20.7904 - accuracy: 0.1722
# Epoch 2/100
# 3/3 [==============================] - 0s 32ms/step - loss: 8.3876 - accuracy: 0.2333
# Epoch 3/100
# 3/3 [==============================] - 0s 80ms/step - loss: 4.3477 - accuracy: 0.2167
# Epoch 4/100
# 3/3 [==============================] - 0s 69ms/step - loss: 4.1198 - accuracy: 0.2556
# Epoch 5/100
# 3/3 [==============================] - 0s 69ms/step - loss: 3.7321 - accuracy: 0.1889
# Epoch 6/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3.1800 - accuracy: 0.2389
# Epoch 7/100
# 3/3 [==============================] - 0s 45ms/step - loss: 2.8387 - accuracy: 0.2333
# Epoch 8/100
# 3/3 [==============================] - 0s 69ms/step - loss: 2.8097 - accuracy: 0.1889
# Epoch 9/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4157 - accuracy: 0.2167
# Epoch 10/100
# 3/3 [==============================] - 0s 53ms/step - loss: 2.0827 - accuracy: 0.2667
# Epoch 11/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.9833 - accuracy: 0.2222
# Epoch 12/100
# 3/3 [==============================] - 0s 40ms/step - loss: 2.1023 - accuracy: 0.2556
# Epoch 13/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.8842 - accuracy: 0.2556
# Epoch 14/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.9405 - accuracy: 0.2278
# Epoch 15/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.7825 - accuracy: 0.2444
# Epoch 16/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.8175 - accuracy: 0.2278
# Epoch 17/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.7521 - accuracy: 0.2556
# Epoch 18/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.7789 - accuracy: 0.2722
# Epoch 19/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.7657 - accuracy: 0.2333
# Epoch 20/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.6349 - accuracy: 0.3167
# Epoch 21/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5939 - accuracy: 0.3111
# Epoch 22/100
# 3/3 [==============================] - 0s 91ms/step - loss: 1.6260 - accuracy: 0.3111
# Epoch 23/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.6046 - accuracy: 0.2833
# Epoch 24/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.5138 - accuracy: 0.3778
# Epoch 25/100
# 3/3 [==============================] - 0s 81ms/step - loss: 1.5201 - accuracy: 0.3111
# Epoch 26/100
# 3/3 [==============================] - 0s 57ms/step - loss: 1.5000 - accuracy: 0.3722
# Epoch 27/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.4420 - accuracy: 0.4167
# Epoch 28/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.5682 - accuracy: 0.3056
# Epoch 29/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4846 - accuracy: 0.3333
# Epoch 30/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.5173 - accuracy: 0.3444
# Epoch 31/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4439 - accuracy: 0.3833
# Epoch 32/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1.4426 - accuracy: 0.3833
# Epoch 33/100
# 3/3 [==============================] - 0s 69ms/step - loss: 1.4717 - accuracy: 0.3056
# Epoch 34/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.4429 - accuracy: 0.3778
# Epoch 35/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.4399 - accuracy: 0.3611
# Epoch 36/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4707 - accuracy: 0.3167
# Epoch 37/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.3799 - accuracy: 0.3722
# Epoch 38/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.4250 - accuracy: 0.3611
# Epoch 39/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3366 - accuracy: 0.4111
# Epoch 40/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4900 - accuracy: 0.3000
# Epoch 41/100
# 3/3 [==============================] - 0s 132ms/step - loss: 1.4818 - accuracy: 0.3111
# Epoch 42/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3912 - accuracy: 0.3778
# Epoch 43/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.3519 - accuracy: 0.3722
# Epoch 44/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3476 - accuracy: 0.4056
# Epoch 45/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2927 - accuracy: 0.4444
# Epoch 46/100
# 3/3 [==============================] - 0s 69ms/step - loss: 1.4085 - accuracy: 0.3778
# Epoch 47/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3312 - accuracy: 0.4000
# Epoch 48/100
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3193 - accuracy: 0.4167
# Epoch 49/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3210 - accuracy: 0.4167
# Epoch 50/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3338 - accuracy: 0.4111
# Epoch 51/100
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3137 - accuracy: 0.4222
# Epoch 52/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3216 - accuracy: 0.4222
# Epoch 53/100
# 3/3 [==============================] - 0s 52ms/step - loss: 1.2606 - accuracy: 0.4167
# Epoch 54/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3542 - accuracy: 0.3500
# Epoch 55/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.2073 - accuracy: 0.4611
# Epoch 56/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1925 - accuracy: 0.4889
# Epoch 57/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2281 - accuracy: 0.4444
# Epoch 58/100
# 3/3 [==============================] - 0s 57ms/step - loss: 1.2316 - accuracy: 0.4667
# Epoch 59/100
# 3/3 [==============================] - 0s 81ms/step - loss: 1.2776 - accuracy: 0.4500
# Epoch 60/100
# 3/3 [==============================] - 0s 65ms/step - loss: 1.3292 - accuracy: 0.4167
# Epoch 61/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.2525 - accuracy: 0.4389
# Epoch 62/100
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2396 - accuracy: 0.4278
# Epoch 63/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2902 - accuracy: 0.4500
# Epoch 64/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.2067 - accuracy: 0.4778
# Epoch 65/100
# 3/3 [==============================] - 0s 58ms/step - loss: 1.2319 - accuracy: 0.4556
# Epoch 66/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2341 - accuracy: 0.4389
# Epoch 67/100
# 3/3 [==============================] - 0s 65ms/step - loss: 1.1765 - accuracy: 0.4611
# Epoch 68/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.2372 - accuracy: 0.4333
# Epoch 69/100
# 3/3 [==============================] - 0s 81ms/step - loss: 1.1606 - accuracy: 0.4833
# Epoch 70/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2043 - accuracy: 0.4667
# Epoch 71/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2229 - accuracy: 0.4611
# Epoch 72/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.1712 - accuracy: 0.4611
# Epoch 73/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.1792 - accuracy: 0.4500
# Epoch 74/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2196 - accuracy: 0.4722
# Epoch 75/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.2037 - accuracy: 0.4278
# Epoch 76/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2220 - accuracy: 0.4222
# Epoch 77/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1295 - accuracy: 0.4833
# Epoch 78/100
# 3/3 [==============================] - 0s 64ms/step - loss: 1.1544 - accuracy: 0.5111
# Epoch 79/100
# 3/3 [==============================] - 0s 76ms/step - loss: 1.1853 - accuracy: 0.4889
# Epoch 80/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1483 - accuracy: 0.4333
# Epoch 81/100
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1538 - accuracy: 0.4667
# Epoch 82/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1299 - accuracy: 0.5000
# Epoch 83/100
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0951 - accuracy: 0.5556
# Epoch 84/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1394 - accuracy: 0.5056
# Epoch 85/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0750 - accuracy: 0.5722
# Epoch 86/100
# 3/3 [==============================] - 0s 86ms/step - loss: 1.1952 - accuracy: 0.4500
# Epoch 87/100
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1534 - accuracy: 0.5167
# Epoch 88/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0224 - accuracy: 0.6000
# Epoch 89/100
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0869 - accuracy: 0.5222
# Epoch 90/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.0913 - accuracy: 0.5278
# Epoch 91/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0249 - accuracy: 0.5333
# Epoch 92/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.0158 - accuracy: 0.5500
# Epoch 93/100
# 3/3 [==============================] - 0s 80ms/step - loss: 1.1877 - accuracy: 0.4278
# Epoch 94/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0588 - accuracy: 0.5000
# Epoch 95/100
# 3/3 [==============================] - 0s 74ms/step - loss: 1.0380 - accuracy: 0.5389
# Epoch 96/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.1225 - accuracy: 0.4889
# Epoch 97/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0488 - accuracy: 0.5889
# Epoch 98/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.0455 - accuracy: 0.5111
# Epoch 99/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0040 - accuracy: 0.5778
# Epoch 100/100
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0257 - accuracy: 0.5611
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_72 (Dense)            (None, 1024)              21504
#
#  dropout_36 (Dropout)        (None, 1024)              0
#
#  dense_73 (Dense)            (None, 512)               524800
#
#  dropout_37 (Dropout)        (None, 512)               0
#
#  dense_74 (Dense)            (None, 256)               131328
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  dense_75 (Dense)            (None, 128)               32896
#
#  dense_76 (Dense)            (None, 64)                8256
#
#  dense_77 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 719109 (2.74 MB)
# Trainable params: 719109 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 6/6 [==============================] - 2s 9ms/step - loss: 0.8937 - accuracy: 0.6333
# 1/1 [==============================] - 1s 1s/step
# Fold 4
# Percentage of Data for Training: 90.00%
# Percentage of Data for Testing: 10.00%
# Epoch 1/100
# 3/3 [==============================] - 13s 44ms/step - loss: 10.5021 - accuracy: 0.1611
# Epoch 2/100
# 3/3 [==============================] - 0s 38ms/step - loss: 7.6056 - accuracy: 0.1444
# Epoch 3/100
# 3/3 [==============================] - 0s 33ms/step - loss: 4.7013 - accuracy: 0.1778
# Epoch 4/100
# 3/3 [==============================] - 0s 59ms/step - loss: 3.3958 - accuracy: 0.2056
# Epoch 5/100
# 3/3 [==============================] - 0s 46ms/step - loss: 3.6678 - accuracy: 0.2222
# Epoch 6/100
# 3/3 [==============================] - 0s 64ms/step - loss: 3.0871 - accuracy: 0.1944
# Epoch 7/100
# 3/3 [==============================] - 0s 37ms/step - loss: 2.4873 - accuracy: 0.2667
# Epoch 8/100
# 3/3 [==============================] - 0s 35ms/step - loss: 2.7484 - accuracy: 0.2000
# Epoch 9/100
# 3/3 [==============================] - 0s 33ms/step - loss: 2.3267 - accuracy: 0.2667
# Epoch 10/100
# 3/3 [==============================] - 0s 43ms/step - loss: 2.0984 - accuracy: 0.2722
# Epoch 11/100
# 3/3 [==============================] - 0s 45ms/step - loss: 2.2579 - accuracy: 0.1722
# Epoch 12/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8931 - accuracy: 0.2889
# Epoch 13/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.8564 - accuracy: 0.2556
# Epoch 14/100
# 3/3 [==============================] - 0s 31ms/step - loss: 2.0206 - accuracy: 0.1889
# Epoch 15/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.6668 - accuracy: 0.3278
# Epoch 16/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.6533 - accuracy: 0.2889
# Epoch 17/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.6983 - accuracy: 0.2667
# Epoch 18/100
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5534 - accuracy: 0.3000
# Epoch 19/100
# 3/3 [==============================] - 0s 69ms/step - loss: 1.5815 - accuracy: 0.3000
# Epoch 20/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.6374 - accuracy: 0.2500
# Epoch 21/100
# 3/3 [==============================] - 0s 86ms/step - loss: 1.6269 - accuracy: 0.2889
# Epoch 22/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4918 - accuracy: 0.2944
# Epoch 23/100
# 3/3 [==============================] - 0s 57ms/step - loss: 1.5832 - accuracy: 0.3000
# Epoch 24/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.5643 - accuracy: 0.3444
# Epoch 25/100
# 3/3 [==============================] - 0s 83ms/step - loss: 1.5218 - accuracy: 0.3167
# Epoch 26/100
# 3/3 [==============================] - 0s 108ms/step - loss: 1.5221 - accuracy: 0.3333
# Epoch 27/100
# 3/3 [==============================] - 0s 85ms/step - loss: 1.5159 - accuracy: 0.3333
# Epoch 28/100
# 3/3 [==============================] - 0s 107ms/step - loss: 1.4553 - accuracy: 0.3556
# Epoch 29/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4893 - accuracy: 0.2611
# Epoch 30/100
# 3/3 [==============================] - 0s 67ms/step - loss: 1.5158 - accuracy: 0.3056
# Epoch 31/100
# 3/3 [==============================] - 0s 77ms/step - loss: 1.4527 - accuracy: 0.3556
# Epoch 32/100
# 3/3 [==============================] - 0s 96ms/step - loss: 1.4167 - accuracy: 0.3444
# Epoch 33/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.4929 - accuracy: 0.3222
# Epoch 34/100
# 3/3 [==============================] - 0s 112ms/step - loss: 1.4592 - accuracy: 0.3333
# Epoch 35/100
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4433 - accuracy: 0.3389
# Epoch 36/100
# 3/3 [==============================] - 0s 83ms/step - loss: 1.4385 - accuracy: 0.4000
# Epoch 37/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3600 - accuracy: 0.3611
# Epoch 38/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4158 - accuracy: 0.3889
# Epoch 39/100
# 3/3 [==============================] - 0s 103ms/step - loss: 1.4167 - accuracy: 0.3500
# Epoch 40/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3518 - accuracy: 0.3889
# Epoch 41/100
# 3/3 [==============================] - 0s 97ms/step - loss: 1.4111 - accuracy: 0.3833
# Epoch 42/100
# 3/3 [==============================] - 0s 97ms/step - loss: 1.4482 - accuracy: 0.3389
# Epoch 43/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3862 - accuracy: 0.3500
# Epoch 44/100
# 3/3 [==============================] - 0s 94ms/step - loss: 1.3241 - accuracy: 0.4333
# Epoch 45/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.3592 - accuracy: 0.3556
# Epoch 46/100
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3450 - accuracy: 0.3667
# Epoch 47/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.3402 - accuracy: 0.3778
# Epoch 48/100
# 3/3 [==============================] - 0s 105ms/step - loss: 1.3804 - accuracy: 0.3611
# Epoch 49/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3497 - accuracy: 0.3722
# Epoch 50/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3324 - accuracy: 0.3556
# Epoch 51/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3009 - accuracy: 0.3556
# Epoch 52/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.3103 - accuracy: 0.4333
# Epoch 53/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.2981 - accuracy: 0.4056
# Epoch 54/100
# 3/3 [==============================] - 0s 57ms/step - loss: 1.2979 - accuracy: 0.4000
# Epoch 55/100
# 3/3 [==============================] - 0s 91ms/step - loss: 1.2702 - accuracy: 0.3889
# Epoch 56/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1.3507 - accuracy: 0.3167
# Epoch 57/100
# 3/3 [==============================] - 0s 75ms/step - loss: 1.3312 - accuracy: 0.3833
# Epoch 58/100
# 3/3 [==============================] - 0s 115ms/step - loss: 1.2878 - accuracy: 0.4167
# Epoch 59/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.3595 - accuracy: 0.3500
# Epoch 60/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2068 - accuracy: 0.4444
# Epoch 61/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.3083 - accuracy: 0.3722
# Epoch 62/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.2799 - accuracy: 0.4278
# Epoch 63/100
# 3/3 [==============================] - 0s 67ms/step - loss: 1.2675 - accuracy: 0.4167
# Epoch 64/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.2432 - accuracy: 0.4000
# Epoch 65/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1898 - accuracy: 0.4722
# Epoch 66/100
# 3/3 [==============================] - 0s 74ms/step - loss: 1.2734 - accuracy: 0.4056
# Epoch 67/100
# 3/3 [==============================] - 0s 79ms/step - loss: 1.2249 - accuracy: 0.4444
# Epoch 68/100
# 3/3 [==============================] - 0s 65ms/step - loss: 1.1942 - accuracy: 0.4778
# Epoch 69/100
# 3/3 [==============================] - 0s 80ms/step - loss: 1.2387 - accuracy: 0.4056
# Epoch 70/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.2621 - accuracy: 0.3889
# Epoch 71/100
# 3/3 [==============================] - 0s 66ms/step - loss: 1.2289 - accuracy: 0.4444
# Epoch 72/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2078 - accuracy: 0.4444
# Epoch 73/100
# 3/3 [==============================] - 0s 94ms/step - loss: 1.2052 - accuracy: 0.4222
# Epoch 74/100
# 3/3 [==============================] - 0s 103ms/step - loss: 1.1798 - accuracy: 0.4722
# Epoch 75/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.1662 - accuracy: 0.4667
# Epoch 76/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1934 - accuracy: 0.4667
# Epoch 77/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2417 - accuracy: 0.4667
# Epoch 78/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.2060 - accuracy: 0.4611
# Epoch 79/100
# 3/3 [==============================] - 0s 94ms/step - loss: 1.2101 - accuracy: 0.4222
# Epoch 80/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.1671 - accuracy: 0.4278
# Epoch 81/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.1894 - accuracy: 0.4167
# Epoch 82/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.2135 - accuracy: 0.4278
# Epoch 83/100
# 3/3 [==============================] - 0s 76ms/step - loss: 1.1505 - accuracy: 0.4333
# Epoch 84/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.2238 - accuracy: 0.4333
# Epoch 85/100
# 3/3 [==============================] - 0s 97ms/step - loss: 1.1866 - accuracy: 0.4389
# Epoch 86/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.2201 - accuracy: 0.4500
# Epoch 87/100
# 3/3 [==============================] - 0s 81ms/step - loss: 1.1690 - accuracy: 0.4889
# Epoch 88/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.1909 - accuracy: 0.4722
# Epoch 89/100
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1376 - accuracy: 0.4944
# Epoch 90/100
# 3/3 [==============================] - 0s 84ms/step - loss: 1.2311 - accuracy: 0.4444
# Epoch 91/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1044 - accuracy: 0.5000
# Epoch 92/100
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1610 - accuracy: 0.4889
# Epoch 93/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.1755 - accuracy: 0.4833
# Epoch 94/100
# 3/3 [==============================] - 0s 105ms/step - loss: 1.1129 - accuracy: 0.5444
# Epoch 95/100
# 3/3 [==============================] - 0s 83ms/step - loss: 1.1279 - accuracy: 0.5000
# Epoch 96/100
# 3/3 [==============================] - 0s 65ms/step - loss: 1.1227 - accuracy: 0.4944
# Epoch 97/100
# 3/3 [==============================] - 0s 71ms/step - loss: 1.1368 - accuracy: 0.4778
# Epoch 98/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.1264 - accuracy: 0.4333
# Epoch 99/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1648 - accuracy: 0.4944
# Epoch 100/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1051 - accuracy: 0.4944
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_78 (Dense)            (None, 1024)              21504
#
#  dropout_39 (Dropout)        (None, 1024)              0
#
#  dense_79 (Dense)            (None, 512)               524800
#
#  dropout_40 (Dropout)        (None, 512)               0
#
#  dense_80 (Dense)            (None, 256)               131328
#
#  dropout_41 (Dropout)        (None, 256)               0
#
#  dense_81 (Dense)            (None, 128)               32896
#
#  dense_82 (Dense)            (None, 64)                8256
#
#  dense_83 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 719109 (2.74 MB)
# Trainable params: 719109 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 6/6 [==============================] - 3s 12ms/step - loss: 1.0354 - accuracy: 0.5167
# 1/1 [==============================] - 1s 1s/step
# Fold 5
# Percentage of Data for Training: 90.00%
# Percentage of Data for Testing: 10.00%
# Epoch 1/100
# 3/3 [==============================] - 13s 74ms/step - loss: 15.9139 - accuracy: 0.2444
# Epoch 2/100
# 3/3 [==============================] - 0s 28ms/step - loss: 5.9956 - accuracy: 0.2500
# Epoch 3/100
# 3/3 [==============================] - 0s 29ms/step - loss: 6.3186 - accuracy: 0.1722
# Epoch 4/100
# 3/3 [==============================] - 0s 51ms/step - loss: 5.7915 - accuracy: 0.2556
# Epoch 5/100
# 3/3 [==============================] - 0s 46ms/step - loss: 3.9265 - accuracy: 0.2389
# Epoch 6/100
# 3/3 [==============================] - 0s 69ms/step - loss: 3.1797 - accuracy: 0.1722
# Epoch 7/100
# 3/3 [==============================] - 0s 65ms/step - loss: 2.9043 - accuracy: 0.1833
# Epoch 8/100
# 3/3 [==============================] - 0s 36ms/step - loss: 2.2923 - accuracy: 0.2278
# Epoch 9/100
# ...
# Epoch 77/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1129 - accuracy: 0.4944
# Epoch 78/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1770 - accuracy: 0.4778
# Epoch 79/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1306 - accuracy: 0.5111
# Epoch 80/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.0994 - accuracy: 0.5333
# Epoch 81/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.0775 - accuracy: 0.5278
# Epoch 82/100
# 3/3 [==============================] - 0s 78ms/step - loss: 1.0489 - accuracy: 0.5111
# Epoch 83/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1354 - accuracy: 0.5167
# Epoch 84/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1090 - accuracy: 0.5333
# Epoch 85/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0908 - accuracy: 0.5556
# Epoch 86/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1162 - accuracy: 0.5056
# Epoch 87/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0870 - accuracy: 0.5056
# Epoch 88/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1191 - accuracy: 0.5500
# Epoch 89/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0564 - accuracy: 0.5722
# Epoch 90/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0760 - accuracy: 0.5722
# Epoch 91/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.0704 - accuracy: 0.5278
# Epoch 92/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0363 - accuracy: 0.5333
# Epoch 93/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0233 - accuracy: 0.6000
# Epoch 94/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0329 - accuracy: 0.5389
# Epoch 95/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0953 - accuracy: 0.4889
# Epoch 96/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0211 - accuracy: 0.5667
# Epoch 97/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0106 - accuracy: 0.5333
# Epoch 98/100
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0200 - accuracy: 0.5889
# Epoch 99/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9662 - accuracy: 0.5889
# Epoch 100/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.9676 - accuracy: 0.6111
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_108 (Dense)           (None, 1024)              21504
#
#  dropout_54 (Dropout)        (None, 1024)              0
#
#  dense_109 (Dense)           (None, 512)               524800
#
#  dropout_55 (Dropout)        (None, 512)               0
#
#  dense_110 (Dense)           (None, 256)               131328
#
#  dropout_56 (Dropout)        (None, 256)               0
#
#  dense_111 (Dense)           (None, 128)               32896
#
#  dense_112 (Dense)           (None, 64)                8256
#
#  dense_113 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 719109 (2.74 MB)
# Trainable params: 719109 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 6/6 [==============================] - 2s 6ms/step - loss: 0.8716 - accuracy: 0.6611
# 1/1 [==============================] - 1s 1s/step
# Fold 10
# Percentage of Data for Training: 90.00%
# Percentage of Data for Testing: 10.00%
# Epoch 1/100
# 3/3 [==============================] - 14s 39ms/step - loss: 13.2629 - accuracy: 0.1556
# Epoch 2/100
# 3/3 [==============================] - 0s 55ms/step - loss: 7.0280 - accuracy: 0.1833
# Epoch 3/100
# 3/3 [==============================] - 0s 47ms/step - loss: 4.4995 - accuracy: 0.1778
# Epoch 4/100
# 3/3 [==============================] - 0s 39ms/step - loss: 3.6680 - accuracy: 0.2278
# Epoch 5/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2.9826 - accuracy: 0.2833
# Epoch 6/100
# 3/3 [==============================] - 0s 47ms/step - loss: 2.8258 - accuracy: 0.2056
# Epoch 7/100
# 3/3 [==============================] - 0s 39ms/step - loss: 2.6131 - accuracy: 0.1722
# Epoch 8/100
# 3/3 [==============================] - 0s 63ms/step - loss: 2.4853 - accuracy: 0.2333
# Epoch 9/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8990 - accuracy: 0.2667
# Epoch 10/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.9022 - accuracy: 0.2667
# Epoch 11/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2.1039 - accuracy: 0.1611
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8836 - accuracy: 0.2111
# Epoch 13/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8991 - accuracy: 0.2000
# Epoch 14/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.7865 - accuracy: 0.2722
# Epoch 15/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.7468 - accuracy: 0.2444
# Epoch 16/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.7227 - accuracy: 0.2389
# Epoch 17/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.6105 - accuracy: 0.3167
# Epoch 18/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.6847 - accuracy: 0.3000
# Epoch 19/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5206 - accuracy: 0.3611
# Epoch 20/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.6590 - accuracy: 0.3222
# Epoch 21/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5078 - accuracy: 0.3500
# Epoch 22/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5583 - accuracy: 0.3000
# Epoch 23/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.4872 - accuracy: 0.3611
# Epoch 24/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5104 - accuracy: 0.3222
# Epoch 25/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.4861 - accuracy: 0.3000
# Epoch 26/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.4594 - accuracy: 0.3556
# Epoch 27/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5109 - accuracy: 0.3389
# Epoch 28/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4090 - accuracy: 0.3944
# Epoch 29/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3594 - accuracy: 0.3889
# Epoch 30/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3888 - accuracy: 0.3833
# Epoch 31/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3619 - accuracy: 0.3889
# Epoch 32/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3928 - accuracy: 0.4056
# Epoch 33/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4279 - accuracy: 0.3556
# Epoch 34/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3322 - accuracy: 0.4444
# Epoch 35/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3618 - accuracy: 0.3722
# Epoch 36/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.4272 - accuracy: 0.3056
# Epoch 37/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.2859 - accuracy: 0.4111
# Epoch 38/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4083 - accuracy: 0.3778
# Epoch 39/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3467 - accuracy: 0.4278
# Epoch 40/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.2984 - accuracy: 0.4500
# Epoch 41/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3824 - accuracy: 0.3833
# Epoch 42/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3635 - accuracy: 0.3778
# Epoch 43/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3287 - accuracy: 0.3833
# Epoch 44/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.2391 - accuracy: 0.4611
# Epoch 45/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2896 - accuracy: 0.4000
# Epoch 46/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2714 - accuracy: 0.4722
# Epoch 47/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2726 - accuracy: 0.3833
# Epoch 48/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3254 - accuracy: 0.3389
# Epoch 49/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3061 - accuracy: 0.4111
# Epoch 50/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1792 - accuracy: 0.4778
# Epoch 51/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2631 - accuracy: 0.4167
# Epoch 52/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2651 - accuracy: 0.4167
# Epoch 53/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1983 - accuracy: 0.4500
# Epoch 54/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.2596 - accuracy: 0.4556
# Epoch 55/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1818 - accuracy: 0.4667
# Epoch 56/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2442 - accuracy: 0.4056
# Epoch 57/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1709 - accuracy: 0.4722
# Epoch 58/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1974 - accuracy: 0.4889
# Epoch 59/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.1844 - accuracy: 0.5111
# Epoch 60/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2385 - accuracy: 0.4667
# Epoch 61/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.1248 - accuracy: 0.5167
# Epoch 62/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2045 - accuracy: 0.4500
# Epoch 63/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1848 - accuracy: 0.4611
# Epoch 64/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0766 - accuracy: 0.4778
# Epoch 65/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.1893 - accuracy: 0.5000
# Epoch 66/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1527 - accuracy: 0.4833
# Epoch 67/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2013 - accuracy: 0.4833
# Epoch 68/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1029 - accuracy: 0.5000
# Epoch 69/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1701 - accuracy: 0.4611
# Epoch 70/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1895 - accuracy: 0.4722
# Epoch 71/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1622 - accuracy: 0.5056
# Epoch 72/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.1331 - accuracy: 0.5056
# Epoch 73/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1187 - accuracy: 0.4889
# Epoch 74/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1379 - accuracy: 0.5389
# Epoch 75/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1784 - accuracy: 0.4944
# Epoch 76/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1696 - accuracy: 0.4889
# Epoch 77/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1086 - accuracy: 0.5111
# Epoch 78/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0431 - accuracy: 0.5167
# Epoch 79/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1064 - accuracy: 0.5278
# Epoch 80/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.0753 - accuracy: 0.6000
# Epoch 81/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0543 - accuracy: 0.5111
# Epoch 82/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0803 - accuracy: 0.5556
# Epoch 83/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1008 - accuracy: 0.4889
# Epoch 84/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1077 - accuracy: 0.5000
# Epoch 85/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0582 - accuracy: 0.5389
# Epoch 86/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.0223 - accuracy: 0.5667
# Epoch 87/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.0542 - accuracy: 0.5000
# Epoch 88/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0822 - accuracy: 0.5222
# Epoch 89/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0568 - accuracy: 0.5722
# Epoch 90/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0089 - accuracy: 0.5944
# Epoch 91/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9953 - accuracy: 0.5778
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9735 - accuracy: 0.6167
# Epoch 93/100
# 3/3 [==============================] - 0s 58ms/step - loss: 1.0866 - accuracy: 0.5278
# Epoch 94/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0010 - accuracy: 0.5833
# Epoch 95/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0861 - accuracy: 0.5333
# Epoch 96/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.9579 - accuracy: 0.5778
# Epoch 97/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9802 - accuracy: 0.6000
# Epoch 98/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0024 - accuracy: 0.5444
# Epoch 99/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0558 - accuracy: 0.5333
# Epoch 100/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0178 - accuracy: 0.5833
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_114 (Dense)           (None, 1024)              21504
#
#  dropout_57 (Dropout)        (None, 1024)              0
#
#  dense_115 (Dense)           (None, 512)               524800
#
#  dropout_58 (Dropout)        (None, 512)               0
#
#  dense_116 (Dense)           (None, 256)               131328
#
#  dropout_59 (Dropout)        (None, 256)               0
#
#  dense_117 (Dense)           (None, 128)               32896
#
#  dense_118 (Dense)           (None, 64)                8256
#
#  dense_119 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 719109 (2.74 MB)
# Trainable params: 719109 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 6/6 [==============================] - 1s 15ms/step - loss: 0.8563 - accuracy: 0.6778
# 1/1 [==============================] - 1s 1s/step

# %%
# Access and print the random state
print("Random State:", kf.random_state)
# Out:
# Random State: 166

# %%
# Menampilkan hasil prediksi, metrik evaluasi, dan laporan klasifikasi untuk setiap fold
for i in range(1, fold-1):
    print(f"\nResults for Fold {i}:")
    print(f"Training Accuracy: {train_accuracies[i-1]}")
    print(f"Testing Accuracy: {testing_accuracies[i-1]}")
    print(f"Loss: {losses[i-1]}")
    print(f"Training Time: {training_times[i-1]} seconds")
    print("Precision Scores:", precicion_scores[i-1])
    print("Recall Scores:", recall_scores[i-1])
    print("F1 Scores:", f1_scores[i-1])
    print("Classification Report:\n", classification_reports[i-1])

    # Optional: Menampilkan prediksi untuk setiap fold
    fold_predictions = all_predictions[i-1]
    true_labels = fold_predictions['true_labels']
    predicted_labels = fold_predictions['predicted_labels']
    for true, pred in zip(true_labels, predicted_labels):
        print(f"True Label: {true}, Predicted Label: {pred}")
# Out:
# Results for Fold 1:
# Training Accuracy: 0.6277777552604675
# Testing Accuracy: 0.75
# Loss: 0.9643142819404602
# Training Time: 22.21526074409485 seconds
# Precision Scores: [1.   1.   0.8  0.6  0.75]
# Recall Scores: [0.33333333 0.33333333 0.8        1.         1.        ]
# F1 Scores: [0.5        0.5        0.8        0.75       0.85714286]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       1.00      0.33      0.50         3
#       bayati       1.00      0.33      0.50         3
#        hijaz       0.80      0.80      0.80         5
#     nahawand       0.60      1.00      0.75         3
#         rast       0.75      1.00      0.86         6
#
#     accuracy                           0.75        20
#    macro avg       0.83      0.69      0.68        20
# weighted avg       0.82      0.75      0.72        20
#
# True Label: ajam, Predicted Label: rast
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: ajam
# True Label: bayati, Predicted Label: bayati
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: rast
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
#
# Results for Fold 2:
# Training Accuracy: 0.6222222447395325
# Testing Accuracy: 0.35
# Loss: 0.8605019450187683
# Training Time: 34.23517465591431 seconds
# Precision Scores: [1.         0.         0.42857143 0.125      1.        ]
# Recall Scores: [0.125 0.    0.6   1.    0.5  ]
# F1 Scores: [0.22222222 0.         0.5        0.22222222 0.66666667]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       1.00      0.12      0.22         8
#       bayati       0.00      0.00      0.00         2
#        hijaz       0.43      0.60      0.50         5
#     nahawand       0.12      1.00      0.22         1
#         rast       1.00      0.50      0.67         4
#
#     accuracy                           0.35        20
#    macro avg       0.51      0.45      0.32        20
# weighted avg       0.71      0.35      0.36        20
#
# True Label: ajam, Predicted Label: hijaz
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: bayati
# True Label: ajam, Predicted Label: ajam
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: bayati
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: nahawand, Predicted Label: nahawand
# True Label: rast, Predicted Label: hijaz
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: hijaz
#
# Results for Fold 3:
# Training Accuracy: 0.6333333253860474
# Testing Accuracy: 0.55
# Loss: 0.893658459186554
# Training Time: 29.18053436279297 seconds
# Precision Scores: [0.66666667 0.         0.5        0.5        0.75      ]
# Recall Scores: [0.33333333 0.         0.5        1.         1.        ]
# F1 Scores: [0.44444444 0.         0.5        0.66666667 0.85714286]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.67      0.33      0.44         6
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.50      0.50      0.50         4
#     nahawand       0.50      1.00      0.67         4
#         rast       0.75      1.00      0.86         3
#
#     accuracy                           0.55        20
#    macro avg       0.48      0.57      0.49        20
# weighted avg       0.51      0.55      0.50        20
#
# True Label: ajam, Predicted Label: hijaz
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: bayati
# True Label: ajam, Predicted Label: ajam
# True Label: ajam, Predicted Label: hijaz
# True Label: ajam, Predicted Label: ajam
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: ajam
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: rast
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
#
# Results for Fold 4:
# Training Accuracy: 0.5166666507720947
# Testing Accuracy: 0.5
# Loss: 1.035422444343567
# Training Time: 33.44349479675293 seconds
# Precision Scores: [0.28571429 0.         0.         0.66666667 1.        ]
# Recall Scores: [0.5 0.  0.  0.8 0.8]
# F1 Scores: [0.36363636 0.         0.         0.72727273 0.88888889]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.29      0.50      0.36         4
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.00      0.00      0.00         3
#     nahawand       0.67      0.80      0.73         5
#         rast       1.00      0.80      0.89         5
#
#     accuracy                           0.50        20
#    macro avg       0.39      0.42      0.40        20
# weighted avg       0.47      0.50      0.48        20
#
# True Label: ajam, Predicted Label: hijaz
# True Label: ajam, Predicted Label: ajam
# True Label: ajam, Predicted Label: hijaz
# True Label: ajam, Predicted Label: ajam
# True Label: bayati, Predicted Label: ajam
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: ajam
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: ajam
# True Label: hijaz, Predicted Label: ajam
# True Label: nahawand, Predicted Label: ajam
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: hijaz
#
# Results for Fold 5:
# Training Accuracy: 0.6333333253860474
# Testing Accuracy: 0.3
# Loss: 0.881270170211792
# Training Time: 29.564709663391113 seconds
# Precision Scores: [0.   0.   0.   0.25 1.  ]
# Recall Scores: [0.  0.  0.  0.2 1. ]
# F1 Scores: [0.         0.         0.         0.22222222 1.        ]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         5
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.00      0.00      0.00         2
#     nahawand       0.25      0.20      0.22         5
#         rast       1.00      1.00      1.00         5
#
#     accuracy                           0.30        20
#    macro avg       0.25      0.24      0.24        20
# weighted avg       0.31      0.30      0.31        20
#
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: nahawand
# True Label: ajam, Predicted Label: bayati
# True Label: ajam, Predicted Label: hijaz
# True Label: ajam, Predicted Label: hijaz
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: ajam
# True Label: bayati, Predicted Label: ajam
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: ajam
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: ajam
# True Label: nahawand, Predicted Label: ajam
# True Label: nahawand, Predicted Label: hijaz
# True Label: nahawand, Predicted Label: hijaz
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
#
# Results for Fold 6:
# Training Accuracy: 0.7166666388511658
# Testing Accuracy: 0.25
# Loss: 0.7786933183670044
# Training Time: 37.074547290802 seconds
# Precision Scores: [0.         0.         0.5        0.14285714 0.6       ]
# Recall Scores: [0.         0.         0.14285714 0.33333333 0.75      ]
# F1 Scores: [0.         0.         0.22222222 0.2        0.66666667]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         2
#       bayati       0.00      0.00      0.00         4
#        hijaz       0.50      0.14      0.22         7
#     nahawand       0.14      0.33      0.20         3
#         rast       0.60      0.75      0.67         4
#
#     accuracy                           0.25        20
#    macro avg       0.25      0.25      0.22        20
# weighted avg       0.32      0.25      0.24        20
#
# True Label: ajam, Predicted Label: bayati
# True Label: ajam, Predicted Label: nahawand
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: ajam
# True Label: bayati, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: bayati
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: rast
# True Label: hijaz, Predicted Label: bayati
# True Label: hijaz, Predicted Label: rast
# True Label: nahawand, Predicted Label: bayati
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: bayati
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: hijaz
#
# Results for Fold 7:
# Training Accuracy: 0.699999988079071
# Testing Accuracy: 0.3
# Loss: 0.8469784259796143
# Training Time: 31.618306159973145 seconds
# Precision Scores: [0.         0.         0.         0.5        0.42857143]
# Recall Scores: [0.  0.  0.  0.5 1. ]
# F1 Scores: [0.  0.  0.  0.5 0.6]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         1
#       bayati       0.00      0.00      0.00         5
#        hijaz       0.00      0.00      0.00         5
#     nahawand       0.50      0.50      0.50         6
#         rast       0.43      1.00      0.60         3
#
#     accuracy                           0.30        20
#    macro avg       0.19      0.30      0.22        20
# weighted avg       0.21      0.30      0.24        20
#
# True Label: ajam, Predicted Label: nahawand
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: ajam
# True Label: bayati, Predicted Label: rast
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: ajam
# True Label: hijaz, Predicted Label: rast
# True Label: hijaz, Predicted Label: bayati
# True Label: hijaz, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: rast
# True Label: hijaz, Predicted Label: rast
# True Label: nahawand, Predicted Label: bayati
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: bayati
# True Label: nahawand, Predicted Label: bayati
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
#
# Results for Fold 8:
# Training Accuracy: 0.7444444298744202
# Testing Accuracy: 0.4
# Loss: 0.7943475246429443
# Training Time: 49.01813554763794 seconds
# Precision Scores: [0.33333333 1.         0.         0.33333333 0.75      ]
# Recall Scores: [1.         0.1        0.         0.66666667 1.        ]
# F1 Scores: [0.5        0.18181818 0.         0.44444444 0.85714286]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.33      1.00      0.50         2
#       bayati       1.00      0.10      0.18        10
#        hijaz       0.00      0.00      0.00         2
#     nahawand       0.33      0.67      0.44         3
#         rast       0.75      1.00      0.86         3
#
#     accuracy                           0.40        20
#    macro avg       0.48      0.55      0.40        20
# weighted avg       0.70      0.40      0.34        20
#
# True Label: ajam, Predicted Label: ajam
# True Label: ajam, Predicted Label: ajam
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: ajam
# True Label: bayati, Predicted Label: bayati
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: nahawand
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: ajam
# True Label: bayati, Predicted Label: nahawand
# True Label: hijaz, Predicted Label: ajam
# True Label: hijaz, Predicted Label: rast
# True Label: nahawand, Predicted Label: ajam
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: nahawand
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
#
# Results for Fold 9:
# Training Accuracy: 0.6611111164093018
# Testing Accuracy: 0.45
# Loss: 0.8716365098953247
# Training Time: 27.280797004699707 seconds
# Precision Scores: [0.4  0.25 0.25 0.5  0.8 ]
# Recall Scores: [0.5        0.33333333 0.33333333 0.2        0.8       ]
# F1 Scores: [0.44444444 0.28571429 0.28571429 0.28571429 0.8       ]
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.40      0.50      0.44         4
#       bayati       0.25      0.33      0.29         3
#        hijaz       0.25      0.33      0.29         3
#     nahawand       0.50      0.20      0.29         5
#         rast       0.80      0.80      0.80         5
#
#     accuracy                           0.45        20
#    macro avg       0.44      0.43      0.42        20
# weighted avg       0.48      0.45      0.45        20
#
# True Label: ajam, Predicted Label: ajam
# True Label: ajam, Predicted Label: ajam
# True Label: ajam, Predicted Label: bayati
# True Label: ajam, Predicted Label: nahawand
# True Label: bayati, Predicted Label: hijaz
# True Label: bayati, Predicted Label: bayati
# True Label: bayati, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: hijaz
# True Label: hijaz, Predicted Label: rast
# True Label: hijaz, Predicted Label: ajam
# True Label: nahawand, Predicted Label: bayati
# True Label: nahawand, Predicted Label: nahawand
# True Label: nahawand, Predicted Label: ajam
# True Label: nahawand, Predicted Label: ajam
# True Label: nahawand, Predicted Label: bayati
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: hijaz
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast
# True Label: rast, Predicted Label: rast

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Set font family to Times New Roman
mpl.rcParams['font.family'] = 'Times New Roman'

# Map class indices to specific labels
class_labels = ["ajam", "bayati", "hijaz", "nahawand", "rast"]

# Initialize variables to accumulate confusion matrices
average_cm = np.zeros((5, 5))  # Assuming 5 classes, adjust if necessary

# Loop through all folds
for i, fold_predictions in enumerate(all_predictions):
    print(f"\nResults for Fold {i + 1}:")

    true_labels = fold_predictions['true_labels']
    predicted_labels = fold_predictions['predicted_labels']

    # Create confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Accumulate confusion matrices
    average_cm += cm

    # Plot confusion matrix heatmap with labeled axes
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f'Confusion Matrix - Fold {i + 1}')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()
    
    print("Classification Report:\n", classification_reports[i])

# Calculate the average confusion matrix
average_cm /= len(all_predictions)

# Plot average confusion matrix heatmap with labeled axes
plt.figure(figsize=(8, 6))
sns.heatmap(average_cm, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Average Confusion Matrix Across 10 Folds')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Results for Fold 1:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       1.00      0.33      0.50         3
#       bayati       1.00      0.33      0.50         3
#        hijaz       0.80      0.80      0.80         5
#     nahawand       0.60      1.00      0.75         3
#         rast       0.75      1.00      0.86         6
#
#     accuracy                           0.75        20
#    macro avg       0.83      0.69      0.68        20
# weighted avg       0.82      0.75      0.72        20
#
#
# Results for Fold 2:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       1.00      0.12      0.22         8
#       bayati       0.00      0.00      0.00         2
#        hijaz       0.43      0.60      0.50         5
#     nahawand       0.12      1.00      0.22         1
#         rast       1.00      0.50      0.67         4
#
#     accuracy                           0.35        20
#    macro avg       0.51      0.45      0.32        20
# weighted avg       0.71      0.35      0.36        20
#
#
# Results for Fold 3:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.67      0.33      0.44         6
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.50      0.50      0.50         4
#     nahawand       0.50      1.00      0.67         4
#         rast       0.75      1.00      0.86         3
#
#     accuracy                           0.55        20
#    macro avg       0.48      0.57      0.49        20
# weighted avg       0.51      0.55      0.50        20
#
#
# Results for Fold 4:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.29      0.50      0.36         4
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.00      0.00      0.00         3
#     nahawand       0.67      0.80      0.73         5
#         rast       1.00      0.80      0.89         5
#
#     accuracy                           0.50        20
#    macro avg       0.39      0.42      0.40        20
# weighted avg       0.47      0.50      0.48        20
#
#
# Results for Fold 5:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         5
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.00      0.00      0.00         2
#     nahawand       0.25      0.20      0.22         5
#         rast       1.00      1.00      1.00         5
#
#     accuracy                           0.30        20
#    macro avg       0.25      0.24      0.24        20
# weighted avg       0.31      0.30      0.31        20
#
#
# Results for Fold 6:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         2
#       bayati       0.00      0.00      0.00         4
#        hijaz       0.50      0.14      0.22         7
#     nahawand       0.14      0.33      0.20         3
#         rast       0.60      0.75      0.67         4
#
#     accuracy                           0.25        20
#    macro avg       0.25      0.25      0.22        20
# weighted avg       0.32      0.25      0.24        20
#
#
# Results for Fold 7:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         1
#       bayati       0.00      0.00      0.00         5
#        hijaz       0.00      0.00      0.00         5
#     nahawand       0.50      0.50      0.50         6
#         rast       0.43      1.00      0.60         3
#
#     accuracy                           0.30        20
#    macro avg       0.19      0.30      0.22        20
# weighted avg       0.21      0.30      0.24        20
#
#
# Results for Fold 8:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.33      1.00      0.50         2
#       bayati       1.00      0.10      0.18        10
#        hijaz       0.00      0.00      0.00         2
#     nahawand       0.33      0.67      0.44         3
#         rast       0.75      1.00      0.86         3
#
#     accuracy                           0.40        20
#    macro avg       0.48      0.55      0.40        20
# weighted avg       0.70      0.40      0.34        20
#
#
# Results for Fold 9:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.40      0.50      0.44         4
#       bayati       0.25      0.33      0.29         3
#        hijaz       0.25      0.33      0.29         3
#     nahawand       0.50      0.20      0.29         5
#         rast       0.80      0.80      0.80         5
#
#     accuracy                           0.45        20
#    macro avg       0.44      0.43      0.42        20
# weighted avg       0.48      0.45      0.45        20
#
#
# Results for Fold 10:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.40      0.80      0.53         5
#       bayati       0.00      0.00      0.00         4
#        hijaz       0.50      0.50      0.50         4
#     nahawand       0.33      0.20      0.25         5
#         rast       1.00      1.00      1.00         2
#
#     accuracy                           0.45        20
#    macro avg       0.45      0.50      0.46        20
# weighted avg       0.38      0.45      0.40        20

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Set font family to Times New Roman
mpl.rcParams['font.family'] = 'Times New Roman'

# Map class indices to specific labels
class_labels = ["ajam", "bayati", "hijaz", "nahawand", "rast"]

# Initialize variables to accumulate confusion matrices and classification reports
average_cm = np.zeros((5, 5))  # Assuming 5 classes, adjust if necessary
average_classification_report = {
    'precision': np.zeros(5),
    'recall': np.zeros(5),
    'f1-score': np.zeros(5),
    'support': np.zeros(5)
}

# Loop through all folds
for i, fold_predictions in enumerate(all_predictions):
    print(f"\nResults for Fold {i + 1}:")

    true_labels = fold_predictions['true_labels']
    predicted_labels = fold_predictions['predicted_labels']

    # Create confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Normalize confusion matrix to percentages
    cm_percentage = (cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]) * 100

    # Accumulate confusion matrices
    average_cm += cm_percentage

    # Display confusion matrix heatmap with labeled axes
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f'Confusion Matrix - Fold {i + 1} (Percentage)')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

    # Display classification report
    current_classification_report = classification_report(true_labels, predicted_labels, target_names=class_labels)
    print("Classification Report:\n", current_classification_report)

    # Accumulate classification reports
    average_classification_report_fold = classification_report(true_labels, predicted_labels, target_names=class_labels, output_dict=True)
    for label in class_labels:
        average_classification_report['precision'][class_labels.index(label)] += average_classification_report_fold[label]['precision']
        average_classification_report['recall'][class_labels.index(label)] += average_classification_report_fold[label]['recall']
        average_classification_report['f1-score'][class_labels.index(label)] += average_classification_report_fold[label]['f1-score']
        average_classification_report['support'][class_labels.index(label)] += average_classification_report_fold[label]['support']

# Calculate the average confusion matrix
average_cm /= len(all_predictions)

# Plot average confusion matrix heatmap with labeled axes
plt.figure(figsize=(8, 6))
sns.heatmap(average_cm, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Average Confusion Matrix Across 10 Folds (Percentage)')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()


# Calculate the average values for precision, recall, and F1-score
for metric in ['precision', 'recall', 'f1-score', 'support']:
    average_classification_report[metric] /= len(all_predictions)

# Round the values in the average classification report to two decimal places
for metric in ['precision', 'recall', 'f1-score']:
    average_classification_report[metric] = np.round(average_classification_report[metric], 2)

# Display average classification report
print("\nAverage Classification Report Across 10 Folds:")
average_classification_report_df = pd.DataFrame(average_classification_report, index=class_labels)
print(average_classification_report_df)
# Out:
# Results for Fold 1:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       1.00      0.33      0.50         3
#       bayati       1.00      0.33      0.50         3
#        hijaz       0.80      0.80      0.80         5
#     nahawand       0.60      1.00      0.75         3
#         rast       0.75      1.00      0.86         6
#
#     accuracy                           0.75        20
#    macro avg       0.83      0.69      0.68        20
# weighted avg       0.82      0.75      0.72        20
#
#
# Results for Fold 2:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       1.00      0.12      0.22         8
#       bayati       0.00      0.00      0.00         2
#        hijaz       0.43      0.60      0.50         5
#     nahawand       0.12      1.00      0.22         1
#         rast       1.00      0.50      0.67         4
#
#     accuracy                           0.35        20
#    macro avg       0.51      0.45      0.32        20
# weighted avg       0.71      0.35      0.36        20
#
#
# Results for Fold 3:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.67      0.33      0.44         6
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.50      0.50      0.50         4
#     nahawand       0.50      1.00      0.67         4
#         rast       0.75      1.00      0.86         3
#
#     accuracy                           0.55        20
#    macro avg       0.48      0.57      0.49        20
# weighted avg       0.51      0.55      0.50        20
#
#
# Results for Fold 4:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.29      0.50      0.36         4
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.00      0.00      0.00         3
#     nahawand       0.67      0.80      0.73         5
#         rast       1.00      0.80      0.89         5
#
#     accuracy                           0.50        20
#    macro avg       0.39      0.42      0.40        20
# weighted avg       0.47      0.50      0.48        20
#
#
# Results for Fold 5:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         5
#       bayati       0.00      0.00      0.00         3
#        hijaz       0.00      0.00      0.00         2
#     nahawand       0.25      0.20      0.22         5
#         rast       1.00      1.00      1.00         5
#
#     accuracy                           0.30        20
#    macro avg       0.25      0.24      0.24        20
# weighted avg       0.31      0.30      0.31        20
#
#
# Results for Fold 6:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         2
#       bayati       0.00      0.00      0.00         4
#        hijaz       0.50      0.14      0.22         7
#     nahawand       0.14      0.33      0.20         3
#         rast       0.60      0.75      0.67         4
#
#     accuracy                           0.25        20
#    macro avg       0.25      0.25      0.22        20
# weighted avg       0.32      0.25      0.24        20
#
#
# Results for Fold 7:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.00      0.00      0.00         1
#       bayati       0.00      0.00      0.00         5
#        hijaz       0.00      0.00      0.00         5
#     nahawand       0.50      0.50      0.50         6
#         rast       0.43      1.00      0.60         3
#
#     accuracy                           0.30        20
#    macro avg       0.19      0.30      0.22        20
# weighted avg       0.21      0.30      0.24        20
#
#
# Results for Fold 8:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.33      1.00      0.50         2
#       bayati       1.00      0.10      0.18        10
#        hijaz       0.00      0.00      0.00         2
#     nahawand       0.33      0.67      0.44         3
#         rast       0.75      1.00      0.86         3
#
#     accuracy                           0.40        20
#    macro avg       0.48      0.55      0.40        20
# weighted avg       0.70      0.40      0.34        20
#
#
# Results for Fold 9:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.40      0.50      0.44         4
#       bayati       0.25      0.33      0.29         3
#        hijaz       0.25      0.33      0.29         3
#     nahawand       0.50      0.20      0.29         5
#         rast       0.80      0.80      0.80         5
#
#     accuracy                           0.45        20
#    macro avg       0.44      0.43      0.42        20
# weighted avg       0.48      0.45      0.45        20
#
#
# Results for Fold 10:
# Classification Report:
#                precision    recall  f1-score   support
#
#         ajam       0.40      0.80      0.53         5
#       bayati       0.00      0.00      0.00         4
#        hijaz       0.50      0.50      0.50         4
#     nahawand       0.33      0.20      0.25         5
#         rast       1.00      1.00      1.00         2
#
#     accuracy                           0.45        20
#    macro avg       0.45      0.50      0.46        20
# weighted avg       0.38      0.45      0.40        20
# Average Classification Report Across 10 Folds:
#           precision  recall  f1-score  support
# ajam           0.41    0.36      0.30      4.0
# bayati         0.22    0.08      0.10      4.0
# hijaz          0.30    0.29      0.28      4.0
# nahawand       0.40    0.59      0.43      4.0
# rast           0.81    0.88      0.82      4.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set font family to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Define class labels
class_labels = ['Ajam', 'Bayati', 'Hijaz', 'Nahawand', 'Rast']

# Create arrays for plotting
fold_numbers = np.arange(1, fold)  # Adjust the range to match the actual number of folds
training_accuracies = np.array(train_accuracies)
testing_accuracies = np.array(testing_accuracies)
precision_scores = np.array(precicion_scores)
recall_scores = np.array(recall_scores)
f1_scores = np.array(f1_scores)

# Plotting Accuracy
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
plt.plot(fold_numbers, training_accuracies, label='Training Accuracy', marker='o')
plt.plot(fold_numbers, testing_accuracies, label='Testing Accuracy', marker='o')
plt.title('Accuracy for Each Fold')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.xticks(fold_numbers)  # Set xticks to match the number of folds
plt.legend()

# Plotting Precision
plt.subplot(2, 2, 2)
for class_num in range(precision_scores.shape[1]):
    plt.plot(fold_numbers, precision_scores[:, class_num], label=f'{class_labels[class_num]}', marker='o')
plt.title('Precision for Each Fold')
plt.xlabel('Fold')
plt.ylabel('Precision')
plt.xticks(fold_numbers)  # Set xticks to match the number of folds
plt.legend()

# Plotting Recall
plt.subplot(2, 2, 3)
for class_num in range(recall_scores.shape[1]):
    plt.plot(fold_numbers, recall_scores[:, class_num], label=f'{class_labels[class_num]}', marker='o')
plt.title('Recall for Each Fold')
plt.xlabel('Fold')
plt.ylabel('Recall')
plt.xticks(fold_numbers)  # Set xticks to match the number of folds
plt.legend()

# Plotting F1 Score
plt.subplot(2, 2, 4)
for class_num in range(f1_scores.shape[1]):
    plt.plot(fold_numbers, f1_scores[:, class_num], label=f'{class_labels[class_num]}', marker='o')
plt.title('F1 Score for Each Fold')
plt.xlabel('Fold')
plt.ylabel('F1 Score')
plt.xticks(fold_numbers)  # Set xticks to match the number of folds
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set font family to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Cetak waktu eksekusi training untuk setiap fold
for i, time in enumerate(training_times):
    print(f"Runtime pelatihan fold {i + 1}: {time:.2f} detik")

# Menghitung rata-rata training loss dan akurasi dari masing-masing fold
average_time = np.mean(training_times)

# **Tambahkan total waktu eksekusi**
total_time = np.sum(training_times)

print("----------------------------------------")
print(f"Total waktu eksekusi untuk semua fold: {total_time:.2f} detik")
print(f"Rata-rata waktu eksekusi: {average_time:.2f} detik")

# Choose a color for highlighting and pastel blue for runtime per fold
highlight_color = '#e74c3c'  # Red for average runtime
pastel_blue_color = '#3498db'  # Pastel blue for runtime per fold

# Create a table with runtime information
table_data = [['Fold', 'Runtime (seconds)']]
for i, time in enumerate(training_times):
    table_data.append([f'{i + 1}', f'{time:.2f}'])

# Add the average and total runtime to the table and highlight the corresponding rows
table_data.append(['Average', f'{average_time:.2f}'])
table_data.append(['Total', f'{total_time:.2f}'])
average_row_index = len(table_data) - 2
total_row_index = len(table_data) - 1

# Plot runtime per fold as a line plot
plt.figure(figsize=(16, 6))

# Subplot 1: Line Plot
plt.subplot(1, 2, 1)
plt.plot(range(1, len(training_times) + 1), training_times, marker='o', color=pastel_blue_color, label='Runtime per Fold')
plt.axhline(y=average_time, color=highlight_color, linestyle='--', label='Average Runtime')
plt.axhline(y=total_time, color='green', linestyle='--', label='Total Runtime')  # **Tambahkan garis total waktu**
plt.title('Runtime per Fold', fontsize=16)
plt.xlabel('Fold', fontsize=14)
plt.ylabel('Runtime (seconds)', fontsize=14)
plt.legend()

# Subplot 2: Table
plt.subplot(1, 2, 2)
table = plt.table(cellText=table_data, loc='center', cellLoc='center', colWidths=[0.1, 0.2],
                  cellColours=[['#ecf0f1']*2] * average_row_index + [[highlight_color]*2] +
                               [['#ecf0f1']*2] * (total_row_index - average_row_index - 1) +
                               [['green']*2] +
                               [['#ecf0f1']*2] * (len(training_times) - total_row_index - 1))
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.8, 1.8)  # Adjust the scale to fit the content
plt.axis('off')  # Turn off the axis
plt.title('Runtime Table', fontsize=16)

plt.suptitle('Runtime per Fold, Average Runtime, and Total Runtime', fontsize=20, y=1.05)  # Adjust title position
plt.tight_layout()

plt.show()
# Out:
# Runtime pelatihan fold 1: 22.22 detik
# Runtime pelatihan fold 2: 34.24 detik
# Runtime pelatihan fold 3: 29.18 detik
# Runtime pelatihan fold 4: 33.44 detik
# Runtime pelatihan fold 5: 29.56 detik
# Runtime pelatihan fold 6: 37.07 detik
# Runtime pelatihan fold 7: 31.62 detik
# Runtime pelatihan fold 8: 49.02 detik
# Runtime pelatihan fold 9: 27.28 detik
# Runtime pelatihan fold 10: 24.68 detik
# ----------------------------------------
# Total waktu eksekusi untuk semua fold: 318.31 detik
# Rata-rata waktu eksekusi: 31.83 detik

# %%
# Menampilkan hasil training loss dan akurasi dari masing-masing fold
for i in range(len(losses)):
    print(f"Fold {i+1}: Loss = {losses[i]}, Accuracy = {train_accuracies[i]}")
    
# Menghitung rata-rata training loss dan akurasi dari masing-masing fold
average_loss = np.mean(losses)
average_accuracy = np.mean(train_accuracies)

print("----------------------------------------")
print(f"Rata-rata Loss: {average_loss}")
print(f"Rata-rata Akurasi: {average_accuracy}")
# Out:
# Fold 1: Loss = 0.9643142819404602, Accuracy = 0.6277777552604675
# Fold 2: Loss = 0.8605019450187683, Accuracy = 0.6222222447395325
# Fold 3: Loss = 0.893658459186554, Accuracy = 0.6333333253860474
# Fold 4: Loss = 1.035422444343567, Accuracy = 0.5166666507720947
# Fold 5: Loss = 0.881270170211792, Accuracy = 0.6333333253860474
# Fold 6: Loss = 0.7786933183670044, Accuracy = 0.7166666388511658
# Fold 7: Loss = 0.8469784259796143, Accuracy = 0.699999988079071
# Fold 8: Loss = 0.7943475246429443, Accuracy = 0.7444444298744202
# Fold 9: Loss = 0.8716365098953247, Accuracy = 0.6611111164093018
# Fold 10: Loss = 0.8563240766525269, Accuracy = 0.6777777671813965
# ----------------------------------------
# Rata-rata Loss: 0.8783147156238555
# Rata-rata Akurasi: 0.6533333241939545

# %%
# Membuat plot akurasi
plt.figure(figsize=(10, 5))
plt.plot(range(1, fold ), train_accuracies, marker='o', label='Train Accuracy')
plt.plot(range(1, fold ), testing_accuracies, marker='o', label='Test Accuracy')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy at Every Fold on The Training Dataset')
plt.legend()
plt.show()

# %%
# Menampilkan rata-rata akurasi dari seluruh fold yang dilakukan pada training dan testing
avg_train_accuracy = np.mean(train_accuracies)
avg_test_accuracy = np.mean(testing_accuracies)

print(f"Rata-rata Akurasi Training: {avg_train_accuracy:.4f}")
print(f"Rata-rata Akurasi Testing: {avg_test_accuracy:.4f}")

# Membuat plot akurasi
plt.figure(figsize=(7, 5))
plt.plot(range(1, fold), train_accuracies, marker='o', color='red', label='Train Accuracy')
plt.plot(range(1, fold), testing_accuracies, marker='o', color='green', label='Test Accuracy')
plt.axhline(y=avg_train_accuracy, color='blue', linestyle='--', label=f'Avg Train Acc: {avg_train_accuracy:.4f}')
plt.axhline(y=avg_test_accuracy, color='orange', linestyle='--', label=f'Avg Test Acc: {avg_test_accuracy:.4f}')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy at Every Fold on The Training Dataset')
plt.legend()
plt.show()
# Out:
# Rata-rata Akurasi Training: 0.6533
# Rata-rata Akurasi Testing: 0.4300

# %%
# Convert list testing_accuracies ke dalam numpy array
testing_accuracies_np = np.array(testing_accuracies)

# Hitung standar deviasi
std_deviation = np.std(testing_accuracies_np)

# Tampilkan hasil standar deviasi
print(f"Standar Deviasi Testing Accuracies: {std_deviation}")
# Out:
# Standar Deviasi Testing Accuracies: 0.14

# %%
# Choose a color for highlighting and pastel blue for runtime per fold
highlight_color = '#e74c3c'  # Red for average runtime
pastel_blue_color = '#3498db'  # Pastel blue for runtime per fold

# Calculate the average metrics across all folds
avg_precision = np.mean(precision_scores, axis=0)
avg_recall = np.mean(recall_scores, axis=0)
avg_f1 = np.mean(f1_scores, axis=0)
avg_accuracy = np.mean(testing_accuracies)

# Create a DataFrame for average metrics
average_metrics = pd.DataFrame({
    'Class': ['ajam', 'bayati', 'hijaz', 'nahawand', 'rast'],
    'Precision': avg_precision,
    'Recall': avg_recall,
    'F1 Score': avg_f1
})

# Round average_metrics to two decimal places
average_metrics = average_metrics.round({'Precision': 2, 'Recall': 2, 'F1 Score': 2})

# Display the individual fold accuracies and average metrics
print("\nAll Fold Accuracies:")
for i, accuracy in enumerate(testing_accuracies, start=1):
    print(f"Fold {i} Accuracy: {accuracy}")

print("\nAverage Metrics Across Folds:")
print(average_metrics)

print(f"\nAverage Testing Accuracy Across All Folds: {avg_accuracy:.2f}")

# Plotting accuracy before filtering
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(testing_accuracies_np) + 1), testing_accuracies_np, marker='o', linestyle='-',color=highlight_color, label='Accuracy Before Filtering')
plt.axhline(y=avg_accuracy, color=pastel_blue_color, linestyle='--', label='Average Accuracy')

plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Accuracy Before Filtering')
plt.legend()
plt.show()

print("--------------------------------------------------------------------------------------------------------------------")

# Calculate average accuracy and standard deviation
average_accuracy = np.mean(testing_accuracies_np)
std_deviation = np.std(testing_accuracies_np)

# Filter testing accuracies based on standard deviation
testing_acc_after_std = []

for i, accuracy in enumerate(testing_accuracies_np):
    if average_accuracy - std_deviation <= accuracy <= average_accuracy + std_deviation:
        testing_acc_after_std.append((i + 1, accuracy))  # Include fold information

# Display results
print(f"Average Testing Accuracy: {average_accuracy}")
print(f"Standard Deviation: {std_deviation}")
print(f"Filtered Testing Accuracies within One Standard Deviation:")

for fold_num, acc in testing_acc_after_std:
    print(f"Fold {fold_num} - Accuracy: {acc}")

# Calculate and display precision, recall, and F1 score for filtered accuracies
filtered_predictions = [all_predictions[i - 1] for i, _ in testing_acc_after_std]

# Aggregate predictions from filtered folds
all_true_labels = np.concatenate([pred['true_labels'] for pred in filtered_predictions])
all_predicted_labels = np.concatenate([pred['predicted_labels'] for pred in filtered_predictions])

# Calculate metrics
filtered_precision = precision_score(all_true_labels, all_predicted_labels, average=None)
filtered_recall = recall_score(all_true_labels, all_predicted_labels, average=None)
filtered_f1 = f1_score(all_true_labels, all_predicted_labels, average=None)

# Create a DataFrame for metrics of filtered accuracies
filtered_metrics_df = pd.DataFrame({
    'Class': ['ajam', 'bayati', 'hijaz', 'nahawand', 'rast'],
    'Precision': filtered_precision,
    'Recall': filtered_recall,
    'F1 Score': filtered_f1
})

# Round filtered_metrics_df to two decimal places
filtered_metrics_df = filtered_metrics_df.round({'Precision': 2, 'Recall': 2, 'F1 Score': 2})

# Display metrics for filtered accuracies
print("\nMetrics for Filtered Testing Accuracies:")
print(filtered_metrics_df)

# Display average accuracy for filtered accuracies
print(f"\nAverage Testing Accuracy (Filtered): {average_accuracy:.2f}")

# Plotting accuracy after filtering
filtered_fold_numbers, filtered_accuracies = zip(*testing_acc_after_std)

plt.figure(figsize=(10, 6))
plt.plot(filtered_fold_numbers, filtered_accuracies, marker='o', linestyle='-',color=highlight_color, label='Accuracy After Filtering')
plt.axhline(y=average_accuracy, color=pastel_blue_color, linestyle='--', label='Average Accuracy')

plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Accuracy After Filtering')
plt.legend()
plt.show()
# Out:
# All Fold Accuracies:
# Fold 1 Accuracy: 0.75
# Fold 2 Accuracy: 0.35
# Fold 3 Accuracy: 0.55
# Fold 4 Accuracy: 0.5
# Fold 5 Accuracy: 0.3
# Fold 6 Accuracy: 0.25
# Fold 7 Accuracy: 0.3
# Fold 8 Accuracy: 0.4
# Fold 9 Accuracy: 0.45
# Fold 10 Accuracy: 0.45
#
# Average Metrics Across Folds:
#       Class  Precision  Recall  F1 Score
# 0      ajam       0.41    0.36      0.30
# 1    bayati       0.22    0.08      0.10
# 2     hijaz       0.30    0.29      0.28
# 3  nahawand       0.40    0.59      0.43
# 4      rast       0.81    0.88      0.82
#
# Average Testing Accuracy Across All Folds: 0.43
# --------------------------------------------------------------------------------------------------------------------
# Average Testing Accuracy: 0.43000000000000005
# Standard Deviation: 0.14
# Filtered Testing Accuracies within One Standard Deviation:
# Fold 2 - Accuracy: 0.35
# Fold 3 - Accuracy: 0.55
# Fold 4 - Accuracy: 0.5
# Fold 5 - Accuracy: 0.3
# Fold 7 - Accuracy: 0.3
# Fold 8 - Accuracy: 0.4
# Fold 9 - Accuracy: 0.45
# Fold 10 - Accuracy: 0.45
#
# Metrics for Filtered Testing Accuracies:
#       Class  Precision  Recall  F1 Score
# 0      ajam       0.33    0.37      0.35
# 1    bayati       0.14    0.06      0.09
# 2     hijaz       0.26    0.29      0.27
# 3  nahawand       0.40    0.50      0.44
# 4      rast       0.79    0.87      0.83
#
# Average Testing Accuracy (Filtered): 0.43

# %%
 # Prediksi model
prediction = model.predict(X_test)    
test_pred = np.argmax(prediction, axis=1)
test_pred = label_encoder.inverse_transform(test_pred)
true_y = label_encoder.inverse_transform(np.argmax(to_categorical(y_test), axis=1)[:, 1])
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Hitung confusion matrix
conf_matrix = confusion_matrix(true_y, test_pred)

# Plot confusion matrix
plt.figure(figsize=(7, 5))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Tampilkan classification report
print("\nClassification Report:")
print(classification_report(true_y, test_pred, target_names=label_encoder.classes_, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         ajam     0.4000    0.8000    0.5333        10
#       bayati     0.4000    0.2000    0.2667        10
#        hijaz     0.5000    0.3000    0.3750        10
#     nahawand     0.4000    0.4000    0.4000        10
#         rast     0.7778    0.7000    0.7368        10
#
#     accuracy                         0.4800        50
#    macro avg     0.4956    0.4800    0.4624        50
# weighted avg     0.4956    0.4800    0.4624        50
